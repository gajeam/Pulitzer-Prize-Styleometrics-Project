# %%
# !head ./wiki/wiki-links-abridged.txt
# Out:
# head: cannot open './wiki/wiki-links-abridged.txt' for reading: No such file or directory

# %%
# !head ./wiki/wiki-links-simple-sorted.txt
# Out:
# 1: 1664968
# 2: 3 747213 1664968 1691047 4095634 5535664
# 3: 9 77935 79583 84707 564578 594898 681805 681886 835470 880698 1109091 1125108 1279972 1463445 1497566 1783284 1997564 2006526 2070954 2250217 2268713 2276203 2374802 2571397 2640902 2647217 2732378 2821237 3088028 3092827 3211549 3283735 3491412 3492254 3498305 3505664 3547201 3603437 3617913 3793767 3907547 4021634 4025897 4086017 4183126 4184025 4189168 4192731 4395141 4899940 4987592 4999120 5017477 5149173 5149311 5158741 5223097 5302153 5474252 5535280
# 4: 145
# 5: 8 57544 58089 60048 65880 284186 313376 564578 717529 729993 1097284 1204280 1204407 1255317 1670218 1720928 1850305 2269887 2333350 2359764 2640693 2743982 3303009 3322952 3492254 3573013 3721693 3797343 3797349 3797359 3849461 4033556 4173124 4189215 4207986 4669945 4817900 4901416 5010479 5062062 5072938 5098953 5292042 5429924 5599862 5599863 5689049
# 6: 8
# 7: 8
# 8: 5 57544 58089 59375 64985 313376 704624 717529 729993 1204280 1204407 1254637 1255317 1497566 1720928 1850305 2269887 2333350 2359764 2496900 2640848 2743982 3303009 3322952 3492254 3573013 3797343 3797349 3797359 4033556 4173124 4189168 4206743 4207986 4393611 4813259 4901416 5010479 5062062 5072938 5098953 5292042 5429924 5599862 5599863
# 9: 3 74106 75221 275656 313376 1279972 1565872 1613838 1997564 2640650 3092827 3491412 3492254 3956845 3973207 4025897 4189168 4189215 4813259
# 10: 3

# %%
# !head ./wiki/wiki-titles-sorted.txt
# Out:
# !
# !!
# !!!
# !!!!
# !!!Fuck_You!!!
# !!!Fuck_You!!!_And_Then_Some
# !!!Fuck_You!!!_And_then_Some
# !!!Fuck_You!!!_and_Then_Some
# !!!_(album)
# !!!_(band)

# %%
import networkx as nx

# %%
graph_dict = dict()
l = dict()

with open("./wiki/wiki-links-simple-sorted.txt", "r") as g, open("./wiki/wiki-titles-sorted.txt", "r") as f:
    for line in g:
        text = f.readline()[:-1]
#         print(line, text)
        vertex = int(line.split(": ")[0])
        edges = line.split(":")[1].split()
        edges = set([int(edge) for edge in edges])
#         print(graph_dict, edges)
        graph_dict[vertex] = edges
        l[vertex] = text
        if vertex%300000 == 0:
            print(vertex)
#         if vertex == 10:
#             break
#     print(g)
#     print(l)
    print("Done")
    G=nx.Graph(graph_dict)
    result = nx.closeness_centrality(G)
# Out:
# 300000
# 600000
# 900000
# 1200000
# 1500000
# 1800000
# 2100000
# 2400000
# 2700000
# 3000000
# 3300000
# 3600000
# 3900000
# 4200000
# 4500000
# 4800000
# 5100000
# 5400000
# 5700000
# Done

# %%
with open("../Texts/french_expressions.txt", "r") as f:
    for line in f:
        if len(line) > 1 and line[-2] in r'.]:)"' or ";" in line:
            continue
        print(line)
# Out:
# à gogo
#
# à la
#
# à la carte
#
# à la mode
#
# à propos
#
# accouchement
#
# acquis communautaire
#
# aide-de-camp
#
# aide-mémoire
#
# Allons-y!
#
# amour propre
#
# amuse-bouche or amuse-gueule
#
# ancien régime
#
# aperçu
#
# apéritif or aperitif
#
# appellation contrôlée
#
# supervised use of a name. For the conventional use of the term, see Appellation d'origine contrôlée
#
# appetence
#
# après moi, le déluge
#
# arête
#
# armoire
#
# arrière-pensée
#
# art nouveau
#
# attaché
#
# attaque au fer
#
# au contraire
#
# au courant
#
# au fait
#
# au gratin
#
# au jus
#
# au naturel
#
# au pair
#
# au revoir !
#
# avant la lettre
#
# avoirdupois
#
#
#
# bric-à-brac
#
#
#
# Brioche
#
# baguette
#
# banquette
#
# beaucoup de
#
# beau geste
#
# Beaux-Arts
#
# belle
#
# Belle Époque
#
# belles-lettres
#
# bien entendu
#
# bien pensant
#
# billet-doux
#
# blasé
#
# bon appétit
#
# bon mot (pl. bons mots)
#
# bon vivant
#
# bon voyage
#
# boulevard
#
# bourgeois
#
# bouquet
#
# bric-à-brac
#
# brioche
#
# brunette
#
#
#
# Café au lait
#
#
#
# Chaise longue
#
#
#
# Chauffeur
#
#
#
# Chignon
#
#
#
# Contre-jour
#
#
#
# Creperie
#
# ça ne fait rien
#
# cache
#
# cachet
#
# café
#
# café au lait
#
# calque
#
# canard
#
# canapé
#
# carte blanche
#
# carte de visite
#
#
#
#
#
# chaise longue
#
# Champs-Élysées
#
# chanteuse
#
# chargé d'affaires
#
# chauffeur
#
# chef d'œuvre
#
# cherchez la femme
#
# chez
#
# chic
#
# chignon
#
# cinéma pur
#
# cinéma vérité
#
# cliché
#
# clique
#
# cloisonné
#
# commandant
#
# comme ci, comme ça
#
# communiqué
#
# concierge
#
# concordat
#
# contre-coup
#
# contre-jour
#
# contretemps
#
# coquette
#
# cordon bleu
#
# cordon sanitaire
#
# corniche
#
# cortège
#
# coup de foudre
#
# coup d'état
#
# political coup, government overthrow
#
# coup de grâce
#
# coup de main
#
# coup de maître
#
# stroke of the master, master stroke. This word describes a planned action skilfully done. See also tour de force below
#
# coup de théâtre
#
# coup d'œil
#
# couture
#
# couturier
#
# crèche
#
# crème brûlée
#
# crème de la crème
#
# crème fraîche
#
# crêpe
#
#
#
# Cul-de-sac
#
# crêperie
#
# critique
#
# croissant
#
# cul-de-sac
#
#
#
# Dressage
#
# de rigueur
#
# de trop
#
# déclassé
#
# décolleté
#
# décor
#
# découpage
#
# demi-glace
#
# demi-sec
#
# déjà vu
#
# dénouement
#
# dépanneur
#
# dérailleur
#
# dernier cri
#
# derrière
#
# déshabillé
#
# détente
#
# digestif
#
# directeur sportif
#
# divertissement
#
# dossier
#
# doyen
#
# dressage
#
# droit du seigneur
#
# du jour
#
#
#
# eau de Cologne
#
#
#
# eau de vie
#
#
#
# Entrée
#
#
#
# En plein air
#
#
#
# en pointe
#
# eau de Cologne
#
# eau de toilette
#
# eau de vie
#
# écarté
#
# échappé
#
# éclair
#
# éclat
#
# écorché
#
# élan
#
# élan vital
#
# éminence grise
#
# en banc
#
# en bloc
#
# en garde
#
# en passant
#
# en pointe
#
# en route
#
# on the way
#
# enfant terrible
#
# ennui
#
# entente
#
# entre nous
#
# entrée
#
# entremets
#
# entrepreneur
#
# embonpoint
#
# épater la bourgeoisie or épater le bourgeois
#
# escargot
#
# esprit de corps
#
# esprit de l'escalier
#
# l'État, c'est moi !
#
# étude
#
# étui
#
# excusez-moi
#
# extraordinaire
#
# façade
#
# fait accompli
#
# faute de mieux
#
# faux
#
# faux pas
#
# femme fatale
#
# feuilleton
#
# film noir
#
# fils
#
# fin de siècle
#
# flambé
#
# flambeau
#
# flâneur
#
#
#
# Fleur-de-lis
#
# fleur-de-lis
#
#
#
# Fleur de sel
#
# fleur de sel
#
#
#
# Foie gras
#
# foie gras
#
# folie à deux
#
# force majeure
#
# forte
#
# froideur
#
#
#
# Gendarmes
#
#
#
#
#
# Grenadier
#
# gaffe
#
# blunder
#
# garçon
#
# gauche
#
# gaucherie
#
# gendarme
#
# gendarmerie
#
# a military body charged with police duties
#
# genre
#
# gîte
#
# glissade
#
# Grand Prix
#
# Grand Guignol
#
# grenadier
#
#
#
# Haute couture
#
# habitué
#
# haute couture
#
# haute école
#
# hauteur
#
# haut monde
#
# Honi soit qui mal y pense
#
# hors de combat
#
# hors concours
#
# hors d'œuvre
#
#
#
# Ingénue
#
# idée fixe
#
# impasse
#
# j'accuse
#
# j'adoube
#
# je ne regrette rien
#
# je ne sais quoi
#
# jeu d'esprit
#
# lit. "play of spirit": a witty, often light-hearted, comment or composition
#
# jeunesse dorée
#
# joie de vivre
#
# l'appel du vide
#
# laïcité
#
# laissez-faire
#
# laissez-passer
#
# a travel document, a passport
#
# laissez les bons temps rouler
#
# lamé
#
# lanterne rouge
#
# lèse majesté
#
# liaison
#
# lingerie
#
# littérateur
#
# louche
#
# Louis Quatorze
#
# Louis Quinze
#
#
#
# Macramé
#
#
#
# Mange tout
#
#
#
# Mardi gras
#
# macramé
#
# madame
#
# mademoiselle
#
# malaise
#
# mange tout
#
# manqué
#
# Mardi gras
#
# marque
#
# matériel
#
# mauvais quart d'heure
#
# mélange
#
# mêlée
#
# ménage à trois
#
# métier
#
# milieu
#
# milieu intérieur
#
# mirepoix
#
# mise en place
#
# mise en scène
#
# mise en table
#
# montage
#
# mort de rire or MDR
#
# le mot juste
#
# motif
#
# moue
#
# mousse
#
# né, née
#
# n'est-ce pas?
#
# noblesse oblige
#
# nom de guerre
#
# nom de plume
#
# nouveau riche
#
# nouvelle vague
#
# objet d'art
#
# objet trouvé
#
# œuvre
#
# omelette
#
# opéra bouffe
#
# outré
#
#
#
# Pain au chocolat
#
#
#
# Parkour
#
#
#
# Pince-nez
#
# pain au chocolat
#
# pain aux raisins
#
# panache
#
# papier-mâché
#
# par avion
#
# par excellence
#
# parc fermé
#
# parkour
#
# parole
#
# parvenu
#
# pas de deux
#
# pas de trois
#
# passe-partout
#
# pastiche
#
# patois
#
# père
#
# peloton
#
# petite bourgeoisie
#
# la petite mort
#
# Pied-Noir
#
# pied-à-terre (also pied à terre)
#
# pince-nez
#
# piste
#
# plage
#
# plat du jour
#
# point d'appui
#
# porte cochère
#
# poseur
#
# pot-au-feu
#
# pour encourager les autres
#
# pourboire
#
# prairie
#
# prêt-à-porter
#
# prie-dieu
#
# prix fixe
#
# provocateur
#
# Quai d'Orsay
#
# Quatorze juillet
#
# quelle bonne idée !
#
# What a good idea!
#
# quel dommage !
#
# quel horreur !
#
# quelle surprise !
#
# What a surprising thing!
#
#
#
# Roux
#
# raconteur
#
# raison d'être
#
# rapport
#
# rapprochement
#
# reconnaissance
#
# renaissance
#
# répertoire
#
# reportage
#
# restaurateur
#
# riposte
#
# Rive Gauche
#
# the left (southern) bank (of the River Seine in Paris). A particular mindset attributed to inhabitants of that area, which includes the Sorbonne
#
# roi fainéant
#
# rôle
#
# roman à clef
#
# roué
#
# roux
#
# sang-froid
#
# sans
#
# sans-culottes
#
# sauté
#
# savant
#
# savoir-faire
#
# savoir-vivre
#
# sobriquet
#
# soi-disant
#
# soigné
#
# soirée
#
# sommelier
#
# soupçon
#
# soupe du jour
#
# succès d'estime
#
#
#
# Tableau vivant
#
# tableau
#
# tableau vivant
#
# tenné
#
# tête-à-tête
#
# toilette
#
# torsades de pointes
#
# touché
#
# tout court
#
# tout de suite
#
# tranche
#
# triage
#
#
#
# Trou de loup
#
# tricoteuse
#
# trompe-l'œil
#
# trou de loup
#
# va-et-vient
#
# vin de pays
#
#
#
# Salad with vinaigrette dressing
#
# vinaigrette
#
# vive […]!
#
# vive la différence !
#
# voilà !
#
# volte-face
#
# voulez-vous coucher avec moi (ce soir)?
#
# voyeur
#
# zut alors!
#
#
#
# accoutrement
#
# appliqué
#
# après-ski
#
# artiste
#
# arrêt à bon temps
#
# auteur
#
# au naturel
#
# à la mode
#
# bête noire
#
# boutique
#
# boutonnière
#
# c'est magnifique, mais ce n'est pas la guerre
#
# cause célèbre
#
# chacun à son goût
#
# chanson
#
# château
#
# chef
#
# cinq à sept
#
# claque
#
# connoisseur
#
# corsage
#
# début
#
# décolletage
#
# démarche
#
# dépanneur
#
# émigré
#
# encore
#
# en masse
#
# en suite
#
# entrée
#
# épée
#
# escritoire
#
# exposé
#
# femme
#
# fin de siècle
#
# forte
#
# hors d'oeuvre
#
# la sauce est tout
#
# marquee
#
# nostalgie de la boue
#
# outré
#
# passé
#
# peignoir
#
# pièce d'occasion
#
# potpourri
#
# précis
#
# première
#
# raisonneur
#
# recherché
#
# rendezvous
#
# reprise
#
# résumé
#
# risqué (also risque)
#
# rouge
#
# séance
#
# touché
#
# vignette
#
#
#
# A Canadian aide-de-camp
#
# aide-de-camp
#
# cinquefoil
#
# cri de cœur
#
# demi-monde
#
# double entendre
#
# maître d'
#
# negligée
#
# succès de scandale
#
# voir dire
#
#
#
# SECURITAY
#
# PAN PAN
#
# MAYDAY
#
# SEELONCE
#
# SEELONCE FEE NEE
#
# PRU DONCE
#
# MAY DEE CAL

# %%
import pandas as pd

# %%
df = pd.read_csv("../Texts/latin_expressions.txt", sep='\t')

# %%
df.head()
# Out:
#                                      Latin  \
# 0                               ab absurdo
# 1  ab abusu ad usum non valet consequentia
# 2                               ab aeterno
# 3                               ab antiquo
# 4                           a bene placito
#
#                                         Translation  \
# 0                                   from the absurd
# 1  an inference from an abuse to a use is not valid
# 2                                  from the eternal
# 3                                  from the ancient
# 4                             from one well pleased
#
#                                                Notes
# 0  Said of an argument either for a conclusion th...
# 1  Rights abused are still rights; confer abusus ...
# 2  Literally, "from the everlasting", "from etern...
# 3                                From ancient times.
# 4  Or, "at will" or "at one's pleasure". This phr...

# %% [markdown]
# ## Rule 5 - Never use a foreign phrase, a scientific word, or a jargon word if you can think of an everyday English equivalent.
#
# ### Algorithm
#
# Gather domain specific articles
