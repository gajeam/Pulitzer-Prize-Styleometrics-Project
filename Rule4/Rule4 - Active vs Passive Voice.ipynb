# %% [markdown]
# # Rule 4: Never use the passive where you can use the active.
#
# We are using the dependency parser from Spacy to check for clauses, nouns and verbs which are tagged with a "passive tag". We are simply calculating the number of occurences of sentences that are in the passive voice and returning a decimal number denoting the percentage of articles in the article that are in the passive voice.

# %%
def find_passive_percentage(article):
    '''This function accepts a string of sentences and prints them out classifying them into active or passive.\
    It returns a decimal number to denote the percentage of sentences that are passive.''' 
    
    from spacy.en import English

    parser = English()
    remove_quotes_from_text(article)
    
    parse = parser(article)

    passive_count = 0
    sentence_count = 0
    

    for sentence in parse.sents:
        hasPassive = False
        passive_indicators = []
        for word in sentence:
            if word.dep_ in ['nsubjpass', 'csubjpass', 'auxpass']:
                passive_indicators.append((word.dep_, word.text))
                hasPassive = True
        if hasPassive:
            passive_count += 1
            print("Passive Voice Sentence: {0}.\nPassive Voice indicators: {1}".format(sentence, passive_indicators))
        else:
            print("Active Voice Sentence: {0}".format(sentence))
        sentence_count += 1


    print("The percentage of passive sentences in this article is {0}%".format(round(passive_count*100/sentence_count, 2)))
    return round(passive_count*100/sentence_count, 2)

def remove_quotes_from_text(text):
    # Check for all types of quotes
    import re
    quote_regex = r'"(.*?)"|“(.*?)”'
    text = re.sub(quote_regex, '', text)
    return text

# %%
##Using same article as Gabe's Rule 3 to check my code

with open('gladwell_latebloomers.txt', 'r') as f:
    rule4_percentage = find_passive_percentage(f.read())
    print(rule4_percentage)
# Out:
# Active Voice Sentence: Ben Fountain was an associate in the real-estate practice at the Dallas offices of Akin, Gump, Strauss, Hauer & Feld, just a few years out of law school, when he decided he wanted to write fiction.
# Active Voice Sentence: The only thing Fountain had ever published was a law-review article.
# Active Voice Sentence: His literary training consisted of a handful of creative-writing classes in college.
# Active Voice Sentence: He had tried to write when he came home at night from work, but usually he was too tired to do much.
# Active Voice Sentence: He decided to quit his job.
#
#
# Active Voice Sentence: “
# Active Voice Sentence: I was tremendously apprehensive,” Fountain recalls.
# Active Voice Sentence: “I felt like I’d stepped off a cliff and I didn’t know if the parachute was going to open.
# Active Voice Sentence: Nobody wants to waste their life, and I was doing well at the practice of law.
# Active Voice Sentence: I could have had a good career.
# Active Voice Sentence: And my parents were very proud of me—my dad was so proud of me. . .
# Active Voice Sentence: .
# Active Voice Sentence: It was crazy.
# Active Voice Sentence: ”
#
#
# Active Voice Sentence: He began his new life on a February morning—a Monday.
# Active Voice Sentence: He sat down at his kitchen table at 7:30 A.M. He made a plan.
# Active Voice Sentence: Every day, he would write until lunchtime.
# Active Voice Sentence: Then he would lie down on the floor for twenty minutes to rest his mind.
# Active Voice Sentence: Then he would return to work for a few more hours.
# Active Voice Sentence: He was a lawyer.
# Active Voice Sentence: He had discipline.
# Active Voice Sentence: “I figured out very early on that if I didn’t get my writing done I felt terrible.
# Active Voice Sentence: So I always got my writing done.
# Active Voice Sentence: I treated it like a job.
# Active Voice Sentence: I did not procrastinate.
# Active Voice Sentence: ”
# Active Voice Sentence: His first story was about a stockbroker who uses inside information and crosses a moral line.
# Active Voice Sentence: It was sixty pages long and took him three months to write.
# Active Voice Sentence: When he finished that story, he went back to work and wrote another—and then another.
#
#
# Active Voice Sentence: In his first year, Fountain sold two stories.
# Active Voice Sentence: He gained confidence.
# Active Voice Sentence: He wrote a novel.
# Active Voice Sentence: He decided it wasn’t very good, and he ended up putting it in a drawer.
# Active Voice Sentence: Then came what he describes as his dark period, when he adjusted his expectations and started again.
# Active Voice Sentence: He got a short story published in Harper’s.
# Active Voice Sentence: A New York literary agent saw it and signed him up.
# Active Voice Sentence: He put together a collection of short stories titled “Brief
# Active Voice Sentence: Encounters with Che Guevara,” and Ecco, a HarperCollins imprint, published it.
# Active Voice Sentence: The reviews were sensational.
# Active Voice Sentence: The Times Book Review called it “heartbreaking.
# Active Voice Sentence: ” It won the Hemingway Foundation/PEN award.
# Passive Voice Sentence: It was named a No. 1 Book Sense Pick..
# Passive Voice indicators: [('nsubjpass', 'It'), ('auxpass', 'was')]
# Passive Voice Sentence: It made major regional best-seller lists, was named one of the best books of the year by the San Francisco Chronicle, the Chicago Tribune, and Kirkus Reviews, and drew comparisons to Graham Greene, Evelyn Waugh, Robert Stone, and John le Carré.
#
# Ben Fountain’s rise sounds like a familiar story: the young man from the provinces suddenly takes the literary world by storm..
# Passive Voice indicators: [('auxpass', 'was')]
# Active Voice Sentence: But Ben Fountain’s success was far from sudden.
# Active Voice Sentence: He quit his job at Akin, Gump in 1988.
# Active Voice Sentence: For every story he published in those early years, he had at least thirty rejections.
# Active Voice Sentence: The novel that he put away in a drawer took him four years.
# Active Voice Sentence: The dark period lasted for the entire second half of the nineteen-nineties.
# Active Voice Sentence: His breakthrough with “
# Active Voice Sentence: Brief Encounters” came in 2006, eighteen years after he first sat down to write at his kitchen table.
# Active Voice Sentence: The “young” writer from the provinces took the literary world by storm at the age of forty-eight.
#
#
# Active Voice Sentence: Genius, in the popular conception, is inextricably tied up with precocity—doing something truly creative, we’re inclined to think, requires the freshness and exuberance and energy of youth.
# Active Voice Sentence: Orson Welles made his masterpiece, “
# Active Voice Sentence: Citizen Kane,” at twenty-five.
# Active Voice Sentence: Herman Melville wrote a book a year through his late twenties, culminating, at age thirty-two, with “Moby-Dick.
# Active Voice Sentence: ” Mozart wrote his breakthrough Piano Concerto No. 9 in E-Flat-Major at the age of twenty-one.
# Active Voice Sentence: In some creative forms, like lyric poetry, the importance of precocity has hardened into an iron law.
# Active Voice Sentence: How old was T. S. Eliot when he wrote “
# Active Voice Sentence: The Love Song of J. Alfred Prufrock”
# Active Voice Sentence: (“I grow old . . .
# Active Voice Sentence: I grow old”)?
# Active Voice Sentence: Twenty-three.
# Active Voice Sentence: “
# Active Voice Sentence: Poets peak young,” the creativity researcher James Kaufman maintains.
# Active Voice Sentence: Mihály Csíkszentmihályi, the author of “Flow,” agrees: “
# Passive Voice Sentence: The most creative lyric verse is believed to be that written by the young..
# Passive Voice indicators: [('nsubjpass', 'verse'), ('auxpass', 'is')]
# Active Voice Sentence: ”
# Passive Voice Sentence: According to the Harvard psychologist Howard Gardner, a leading authority on creativity, “Lyric poetry is a domain where talent is discovered early, burns brightly, and then peters out at an early age.”
#
# .
# Passive Voice indicators: [('nsubjpass', 'talent'), ('auxpass', 'is')]
# Active Voice Sentence: A few years ago, an economist at the University of Chicago named David Galenson decided to find out whether this assumption about creativity was true.
# Active Voice Sentence: He looked through forty-seven major poetry anthologies published since 1980 and counted the poems that appear most frequently.
# Passive Voice Sentence: Some people, of course, would quarrel with the notion that literary merit can be quantified..
# Passive Voice indicators: [('nsubjpass', 'merit'), ('auxpass', 'be')]
# Active Voice Sentence: But Galenson simply wanted to poll a broad cross-section of literary scholars about which poems they felt were the most important in the American canon.
# Active Voice Sentence: The top eleven are, in order, T. S. Eliot’s “Prufrock,”
# Active Voice Sentence: Robert Lowell’s “
# Active Voice Sentence: Skunk Hour,” Robert Frost’s “
# Active Voice Sentence: Stopping by Woods on a Snowy Evening,
# Active Voice Sentence: ” William Carlos Williams’s “Red Wheelbarrow,” Elizabeth Bishop’s “
# Active Voice Sentence: The Fish,” Ezra Pound’s “
# Active Voice Sentence: The River Merchant’s Wife,” Sylvia Plath’s “Daddy,” Pound’s “
# Active Voice Sentence: In a Station of the Metro,” Frost’s “Mending Wall,” Wallace Stevens’s “
# Active Voice Sentence: The Snow Man,” and Williams’s “The Dance.
# Active Voice Sentence: ”
# Passive Voice Sentence: Those eleven were composed at the ages of twenty-three, forty-one, forty-eight, forty, twenty-nine, thirty, thirty, twenty-eight, thirty-eight, forty-two, and fifty-nine, respectively..
# Passive Voice indicators: [('auxpass', 'were')]
# Active Voice Sentence: There is no evidence, Galenson concluded, for the notion that lyric poetry is a young person’s game.
# Active Voice Sentence: Some poets do their best work at the beginning of their careers.
# Active Voice Sentence: Others do their best work decades later.
# Passive Voice Sentence: Forty-two per cent of Frost’s anthologized poems were written after the age of fifty..
# Passive Voice indicators: [('nsubjpass', 'cent'), ('nsubjpass', 'poems'), ('auxpass', 'were')]
# Active Voice Sentence: For Williams, it’s forty-four per cent.
# Active Voice Sentence: For Stevens, it’s forty-nine per cent.
#
#
# Active Voice Sentence: The same was true of film, Galenson points out in his study “Old Masters and Young Geniuses: The Two Life Cycles of Artistic Creativity.
# Active Voice Sentence: ” Yes, there was Orson Welles, peaking as a director at twenty-five.
# Active Voice Sentence: But then there was Alfred Hitchcock, who made “
# Active Voice Sentence: Dial M for Murder,”
# Active Voice Sentence: “Rear Window,” “
# Active Voice Sentence: To Catch a Thief,” “
# Active Voice Sentence: The Trouble with Harry,” “Vertigo,” “North by Northwest,” and “Psycho”—one of the greatest runs by a director in history—between his fifty-fourth and sixty-first birthdays.
# Active Voice Sentence: Mark Twain published “
# Active Voice Sentence: Adventures of Huckleberry Finn” at forty-nine.
# Active Voice Sentence: Daniel Defoe wrote “Robinson Crusoe” at fifty-eight.
#
#
# Active Voice Sentence: The examples that Galenson could not get out of his head, however, were Picasso and Cézanne.
# Active Voice Sentence: He was an art lover, and he knew their stories well.
# Active Voice Sentence: Picasso was the incandescent prodigy.
# Active Voice Sentence: His career as a serious artist began with a masterpiece, “
# Active Voice Sentence: Evocation: The Burial of Casagemas,” produced at age twenty.
# Active Voice Sentence: In short order, he painted many of the greatest works of his career—including “
# Active Voice Sentence: Les Demoiselles d’Avignon,” at the age of twenty-six.
# Active Voice Sentence: Picasso fit our usual ideas about genius perfectly.
#
#
# Active Voice Sentence: Cézanne didn’t.
# Passive Voice Sentence: If you go to the Cézanne room at the Musée d’Orsay, in Paris—the finest collection of Cézannes in the world—the array of masterpieces you’ll find along the back wall were all painted at the end of his career..
# Passive Voice indicators: [('auxpass', 'were')]
# Active Voice Sentence: Galenson did a simple economic analysis, tabulating the prices paid at auction for paintings by Picasso and Cézanne with the ages at which they created those works.
# Active Voice Sentence: A painting done by Picasso in his mid-twenties was worth, he found, an average of four times as much as a painting done in his sixties.
# Active Voice Sentence: For Cézanne, the opposite was true.
# Passive Voice Sentence: The paintings he created in his mid-sixties were valued fifteen times as highly as the paintings he created as a young man..
# Passive Voice indicators: [('nsubjpass', 'paintings'), ('auxpass', 'were')]
# Active Voice Sentence: The freshness, exuberance, and energy of youth did little for Cézanne.
# Active Voice Sentence: He was a late bloomer—and for some reason in our accounting of genius and creativity we have forgotten to make sense of the Cézannes of the world.
#
#
# Active Voice Sentence: The first day that Ben Fountain sat down to write at his kitchen table went well.
# Passive Voice Sentence: He knew how the story about the stockbroker was supposed to start..
# Passive Voice indicators: [('nsubjpass', 'story'), ('auxpass', 'was')]
# Active Voice Sentence: But the second day, he says, he “completely freaked out.
# Active Voice Sentence: ”
# Active Voice Sentence: He didn’t know how to describe things.
# Active Voice Sentence: He felt as if he were back in first grade.
# Passive Voice Sentence: He didn’t have a fully formed vision, waiting to be emptied onto the page..
# Passive Voice indicators: [('auxpass', 'be')]
# Active Voice Sentence: “
# Active Voice Sentence: I had to create a mental image of a building, a room, a façade, haircut, clothes—just really basic things,” he says.
# Active Voice Sentence: “I realized I didn’t have the facility to put those into words.
# Active Voice Sentence: I started going out and buying visual dictionaries, architectural dictionaries, and going to school on those.
# Active Voice Sentence: ”
#
#
# Active Voice Sentence: He began to collect articles about things he was interested in, and before long he realized that he had developed a fascination with Haiti.
# Active Voice Sentence: “
# Active Voice Sentence: The Haiti file just kept getting bigger and bigger,” Fountain says.
# Active Voice Sentence: “
# Active Voice Sentence: And I thought, O.K., here’s my novel.
# Active Voice Sentence: For a month or two I said I really don’t need to go there, I can imagine everything.
# Active Voice Sentence: But after a couple of months I thought,
# Active Voice Sentence: Yeah, you’ve got to go there, and so I went, in April or May of ’91.
# Active Voice Sentence: ”
#
#
# Active Voice Sentence: He spoke little French, let alone Haitian Creole.
# Active Voice Sentence: He had never been abroad.
# Active Voice Sentence: Nor did he know anyone in Haiti.
# Active Voice Sentence: “I got to the hotel, walked up the stairs, and there was this guy standing at the top of the stairs,” Fountain recalls.
# Active Voice Sentence: “
# Active Voice Sentence: He said, ‘
# Active Voice Sentence: My name is Pierre.
# Active Voice Sentence: You need a guide.
# Active Voice Sentence: ’
# Active Voice Sentence: I said, ‘You’re sure as hell right, I do.
# Active Voice Sentence: ’
# Active Voice Sentence: He was a very genuine person, and he realized pretty quickly I didn’t want to go see the girls, I didn’t want drugs, I didn’t want any of that other stuff,” Fountain went on. “
# Active Voice Sentence: And then it was, boom, ‘
# Active Voice Sentence: I can take you there.
# Active Voice Sentence: I can take you to this person.’ “
#
#
# Passive Voice Sentence: Fountain was riveted by Haiti..
# Passive Voice indicators: [('nsubjpass', 'Fountain'), ('auxpass', 'was')]
# Active Voice Sentence: “
# Active Voice Sentence: It’s like a laboratory, almost,” he says.
# Active Voice Sentence: “
# Active Voice Sentence: Everything that’s gone on in the last five hundred years—colonialism, race, power, politics, ecological disasters—it’s all there in very concentrated form.
# Active Voice Sentence: And also I just felt, viscerally, pretty comfortable there.
# Active Voice Sentence: ” He made more trips to Haiti, sometimes for a week, sometimes for two weeks.
# Active Voice Sentence: He made friends.
# Active Voice Sentence: He invited them to visit him in Dallas.
# Active Voice Sentence: (“You haven’t lived until you’ve had Haitians stay in your house,” Fountain says.)
# Active Voice Sentence: “
# Passive Voice Sentence: I mean, I was involved..
# Passive Voice indicators: [('nsubjpass', 'I'), ('auxpass', 'was')]
# Active Voice Sentence: I couldn’t just walk away.
# Active Voice Sentence: There’s this very nonrational, nonlinear part of the whole process.
# Active Voice Sentence: I had a pretty specific time era that I was writing about, and certain things that I needed to know.
# Active Voice Sentence: But there were other things I didn’t really need to know.
# Active Voice Sentence: I met a fellow who was with Save the Children, and he was on the Central Plateau, which takes about twelve hours to get to on a bus, and I had no reason to go there.
# Active Voice Sentence: But I went up there.
# Active Voice Sentence: Suffered on that bus, and ate dust.
# Active Voice Sentence: It was a hard trip, but it was a glorious trip.
# Active Voice Sentence: It had nothing to do with the book, but it wasn’t wasted knowledge.”
#
#
# Active Voice Sentence: In “Brief Encounters with Che Guevara,” four of the stories are about Haiti, and they are the strongest in the collection.
# Passive Voice Sentence: They feel like Haiti; they feel as if they’ve been written from the inside looking out, not the outside looking in. “.
# Passive Voice indicators: [('nsubjpass', 'they’ve'), ('auxpass', 'been')]
# Passive Voice Sentence: After the novel was done, I don’t know, I just felt like there was more for me, and I could keep going, keep going deeper there,”.
# Passive Voice indicators: [('nsubjpass', 'novel'), ('auxpass', 'was')]
# Active Voice Sentence: Fountain recalls.
# Active Voice Sentence: “
# Active Voice Sentence: Always there’s
# Active Voice Sentence: something—always something—here for me.
# Active Voice Sentence: How many times have I been?
# Active Voice Sentence: At least thirty times.
# Active Voice Sentence: ”
#
# Prodigies like Picasso, Galenson argues, rarely engage in that kind of open-ended exploration.
# Active Voice Sentence: They tend to be “conceptual,” Galenson says, in the sense that they start with a clear idea of where they want to go, and then they execute it.
# Active Voice Sentence: “I can hardly understand the importance given to the word ‘
# Active Voice Sentence: research,’ “
# Active Voice Sentence: Picasso once said in an interview with the artist Marius de Zayas.
# Active Voice Sentence: “In my opinion, to search means nothing in painting.
# Active Voice Sentence: To find is the thing.
# Active Voice Sentence: ”
# Active Voice Sentence: He continued, “
# Passive Voice Sentence: The several manners I have used in my art must not be considered as an evolution or as steps toward an unknown ideal of painting. . . ..
# Passive Voice indicators: [('nsubjpass', 'manners'), ('auxpass', 'be')]
# Active Voice Sentence: I have never made trials or experiments.
# Active Voice Sentence: ”
#
#
# Active Voice Sentence: But late bloomers, Galenson says, tend to work the other way around.
# Active Voice Sentence: Their approach is experimental.
# Active Voice Sentence: “
# Passive Voice Sentence: Their goals are imprecise, so their procedure is tentative and incremental,” Galenson writes in “Old Masters and Young Geniuses,” and he goes on:
#
# The imprecision of their goals means that these artists rarely feel they have succeeded, and their careers are consequently often dominated by the pursuit of a single objective..
# Passive Voice indicators: [('nsubjpass', 'careers'), ('auxpass', 'are')]
# Active Voice Sentence: These artists repeat themselves, painting the same subject many times, and gradually changing its treatment in an experimental process of trial and error.
# Passive Voice Sentence: Each work leads to the next, and none is generally privileged over others, so experimental painters rarely make specific preparatory sketches or plans for a painting..
# Passive Voice indicators: [('nsubjpass', 'none'), ('auxpass', 'is')]
# Active Voice Sentence: They consider the production of a painting as a process of searching, in which they aim to discover the image in the course of making it; they typically believe that learning is a more important goal than making finished paintings.
# Active Voice Sentence: Experimental artists build their skills gradually over the course of their careers, improving their work slowly over long periods.
# Passive Voice Sentence: These artists are perfectionists and are typically plagued by frustration at their inability to achieve their goal.
#
#
# .
# Passive Voice indicators: [('auxpass', 'are')]
# Active Voice Sentence: Where Picasso wanted to find, not search, Cézanne said the opposite: “I seek in painting.
# Active Voice Sentence: ”
#
#
# Active Voice Sentence: An experimental innovator would go back to Haiti thirty times.
# Active Voice Sentence: That’s how that kind of mind figures out what it wants to do.
# Active Voice Sentence: When Cézanne was painting a portrait of the critic Gustave Geffroy, he made him endure eighty sittings, over three months, before announcing the project a failure.
# Active Voice Sentence: (The result is one of that string of masterpieces in the Musée d’Orsay.)
# Active Voice Sentence: When Cézanne painted his dealer, Ambrose Vollard, he made Vollard arrive at eight in the morning and sit on a rickety platform until eleven-thirty, without a break, on a hundred and fifty occasions—before abandoning the portrait.
# Active Voice Sentence: He would paint a scene, then repaint it, then paint it again.
# Active Voice Sentence: He was notorious for slashing his canvases to pieces in fits of frustration.
#
#
# Active Voice Sentence: Mark Twain was the same way.
# Active Voice Sentence: Galenson quotes the literary critic Franklin Rogers on Twain’s trial-and-error method: “
# Active Voice Sentence: His routine procedure seems to have been to start a novel with some structural plan which ordinarily soon proved defective, whereupon he would cast about for a new plot which would overcome the difficulty, rewrite what he had already written, and then push on until some new defect forced him to repeat the process once again.
# Active Voice Sentence: ”
# Active Voice Sentence: Twain fiddled and despaired and revised and gave up on “Huckleberry Finn”
# Active Voice Sentence: so many times that the book took him nearly a decade to complete.
# Active Voice Sentence: The Cézannes of the world bloom late not as a result of some defect in character, or distraction, or lack of ambition, but because the kind of creativity that proceeds through trial and error necessarily takes a long time to come to fruition.
#
#
# Passive Voice Sentence: One of the best stories in “Brief Encounters” is called “Near-Extinct Birds of the Central Cordillera..
# Passive Voice indicators: [('nsubjpass', 'One'), ('auxpass', 'is')]
# Active Voice Sentence: ” It’s about an ornithologist taken hostage by the FARC guerrillas of Colombia.
# Active Voice Sentence: Like so much of Fountain’s work, it reads with an easy grace.
# Active Voice Sentence: But there was nothing easy or graceful about its creation.
# Active Voice Sentence: “I struggled with that story,” Fountain says.
# Active Voice Sentence: “I always try to do too much.
# Active Voice Sentence: I mean, I probably wrote five hundred pages of it in various incarnations.
# Active Voice Sentence: ”
# Active Voice Sentence: Fountain is at work right now on a novel.
# Passive Voice Sentence: It was supposed to come out this year..
# Passive Voice indicators: [('nsubjpass', 'It'), ('auxpass', 'was')]
# Active Voice Sentence: It’s late.
#
#
# Passive Voice Sentence: Galenson’s idea that creativity can be divided into these types—conceptual and experimental—has a number of important implications..
# Passive Voice indicators: [('nsubjpass', 'creativity'), ('auxpass', 'be')]
# Active Voice Sentence: For example, we sometimes think of late bloomers as late starters.
# Active Voice Sentence: They don’t realize they’re
# Active Voice Sentence: good at something until they’re fifty, so of course they achieve late in life.
# Active Voice Sentence: But that’s not quite right.
# Active Voice Sentence: Cézanne was painting almost as early as Picasso was.
# Passive Voice Sentence: We also sometimes think of them as artists who are discovered late; the world is just slow to appreciate their gifts..
# Passive Voice indicators: [('nsubjpass', 'who'), ('auxpass', 'are')]
# Active Voice Sentence: In both cases, the assumption is that the prodigy and the late bloomer are fundamentally the same, and that late blooming is simply genius under conditions of market failure.
# Active Voice Sentence: What Galenson’s argument suggests is something else—that late bloomers bloom late because they simply aren’t much good until late in their careers.
#
#
# Passive Voice Sentence: “All these qualities of his inner vision were continually hampered and obstructed by Cézanne’s incapacity to give sufficient verisimilitude to the personae of his drama,” the great English art critic Roger Fry wrote of the early Cézanne..
# Passive Voice indicators: [('nsubjpass', 'qualities'), ('auxpass', 'were')]
# Active Voice Sentence: “
# Active Voice Sentence: With all his rare endowments, he happened to lack the comparatively common gift of illustration, the gift that any draughtsman for the illustrated papers learns in a school of commercial art; whereas, to realize such visions as Cézanne’s required this gift in high degree.”
# Active Voice Sentence: In other words, the young Cézanne couldn’t draw.
# Active Voice Sentence: Of “
# Active Voice Sentence: The Banquet,” which Cézanne painted at thirty-one, Fry writes, “It is no use to deny that Cézanne has made a very poor job of it.
# Active Voice Sentence: ”
# Active Voice Sentence: Fry goes on, “
# Active Voice Sentence: More happily endowed and more integral personalities have been able to express themselves harmoniously from the very first.
# Active Voice Sentence: But such rich, complex, and conflicting natures as Cézanne’s require a long period of fermentation.
# Active Voice Sentence: ” Cézanne was trying something so elusive that he couldn’t master it until he’d spent decades practicing.
#
#
# Passive Voice Sentence: This is the vexing lesson of Fountain’s long attempt to get noticed by the literary world..
# Passive Voice indicators: [('auxpass', 'get')]
# Active Voice Sentence: On the road to great achievement, the late bloomer will resemble a failure: while the late bloomer is revising and despairing and changing course and slashing canvases to ribbons after months or years, what he or she produces will look like the kind of thing produced by the artist who will never bloom at all.
# Active Voice Sentence: Prodigies are easy.
# Active Voice Sentence: They advertise their genius from the get-go.
# Active Voice Sentence: Late bloomers are hard.
# Active Voice Sentence: They require forbearance and blind faith.
# Active Voice Sentence: (Let’s just be thankful that Cézanne didn’t have a guidance counsellor in high school who looked at his primitive sketches and told him to try accounting.)
# Active Voice Sentence: Whenever we find a late bloomer, we can’t but wonder how many others like him or her we have thwarted because we prematurely judged their talents.
# Active Voice Sentence: But we also have to accept that there’s nothing we can do about it.
# Active Voice Sentence: How can we ever know which of the failures will end up blooming?
#
#
# Passive Voice Sentence: Not long after meeting Ben Fountain, I went to see the novelist Jonathan Safran Foer, the author of the 2002 best-seller “Everything Is Illuminated..
# Passive Voice indicators: [('nsubjpass', 'novelist'), ('nsubjpass', 'Everything'), ('auxpass', 'Is')]
# Active Voice Sentence: ”
# Active Voice Sentence: Fountain is a graying man, slight and modest, who looks, in the words of a friend of his, like a “golf pro from Augusta, Georgia.
# Active Voice Sentence: ” Foer is in his early thirties and looks barely old enough to drink.
# Active Voice Sentence: Fountain has a softness to him, as if years of struggle have worn away whatever sharp edges he once had.
# Active Voice Sentence: Foer gives the impression that if you touched him while he was in full conversational flight you would get an electric shock.
#
#
# Active Voice Sentence: “I came to writing really by the back door,” Foer said.
# Active Voice Sentence: “
# Active Voice Sentence: My wife is a writer, and she grew up keeping journals—you know, parents said, ‘
# Active Voice Sentence: Lights out, time for bed,’
# Active Voice Sentence: and she had a little flashlight under the covers, reading books.
# Active Voice Sentence: I don’t think I read a book until much later than other people.
# Active Voice Sentence: I just wasn’t interested in it.
# Active Voice Sentence: ”
#
#
# Active Voice Sentence: Foer went to Princeton and took a creative-writing class in his freshman year with Joyce Carol Oates.
# Active Voice Sentence: It was, he explains, “sort of on a whim, maybe out of a sense that I should have a diverse course load.
# Active Voice Sentence: ” He’d never written a story before.
# Active Voice Sentence: “I didn’t really think anything of it, to be honest, but halfway through the semester I arrived to class early one day, and she said, ‘
# Active Voice Sentence: Oh, I’m glad I have this chance to talk to you.
# Active Voice Sentence: I’m a fan of your writing.
# Active Voice Sentence: ’
# Active Voice Sentence: And it was a real revelation for me.”
#
#
# Active Voice Sentence: Oates told him that he had the most important of writerly qualities, which was energy.
# Active Voice Sentence: He had been writing fifteen pages a week for that class, an entire story for each seminar.
# Active Voice Sentence: “
# Active Voice Sentence: Why does a dam with a crack in it leak so much?
# Active Voice Sentence: ” he said, with a laugh.
# Active Voice Sentence: “
# Active Voice Sentence: There was just something in me, there was like a pressure.
# Active Voice Sentence: ”
#
#
# Active Voice Sentence: As a sophomore, he took another creative-writing class.
# Active Voice Sentence: During the following summer, he went to Europe.
# Active Voice Sentence: He wanted to find the village in Ukraine where his grandfather had come from.
# Active Voice Sentence: After the trip, he went to Prague.
# Active Voice Sentence: There he read Kafka, as any literary undergraduate would, and sat down at his computer.
#
#
# Active Voice Sentence: “
# Active Voice Sentence: I was just writing,” he said.
# Active Voice Sentence: “I didn’t know that I was writing until it was happening.
# Active Voice Sentence: I didn’t go with the intention of writing a book.
# Active Voice Sentence: I wrote three hundred pages in ten weeks.
# Active Voice Sentence: I really wrote.
# Active Voice Sentence: I’d never done it like that.
# Active Voice Sentence: ”
#
#
# Active Voice Sentence: It was a novel about a boy named Jonathan Safran Foer who visits the village in Ukraine where his grandfather had come from.
# Active Voice Sentence: Those three hundred pages were the first draft of “
# Active Voice Sentence: Everything Is Illuminated”—the exquisite and extraordinary novel that established Foer as one of the most distinctive literary voices of his generation.
# Active Voice Sentence: He was nineteen years old.
#
#
# Active Voice Sentence: Foer began to talk about the other way of writing books, where you painstakingly honed your craft, over years and years.
# Active Voice Sentence: “I couldn’t do that,” he said.
# Active Voice Sentence: He seemed puzzled by it.
# Active Voice Sentence: It was clear that he had no understanding of how being an experimental innovator would work.
# Active Voice Sentence: “
# Active Voice Sentence: I mean, imagine if the craft you’re trying to learn is to be an original.
# Active Voice Sentence: How could you learn the craft of being an original?
# Active Voice Sentence: ”
#
#
# Active Voice Sentence: He began to describe his visit to Ukraine.
# Active Voice Sentence: “
# Active Voice Sentence: I went to the shtetl where my family came from.
# Passive Voice Sentence: It’s called Trachimbrod, the name I use in the book..
# Passive Voice indicators: [('nsubjpass', 'It')]
# Active Voice Sentence: It’s a real place.
# Active Voice Sentence: But you know what’s funny?
# Active Voice Sentence: It’s the single piece of research that made its way into the book.
# Active Voice Sentence: ” He wrote the first sentence, and he was proud of it, and then he went back and forth in his mind about where to go next.
# Active Voice Sentence: “I spent the first week just having this debate with myself about what to do with this first sentence.
# Active Voice Sentence: And once I made the decision, I felt liberated to just create—and it was very explosive after that.
# Active Voice Sentence: ”
#
#
# Active Voice Sentence: If you read “
# Passive Voice Sentence: Everything Is Illuminated,” you end up with the same feeling you get when you read “.
# Passive Voice indicators: [('nsubjpass', 'Everything'), ('auxpass', 'Is')]
# Active Voice Sentence: Brief Encounters with Che Guevara”—the sense of transport you experience when a work of literature draws you into its own world.
# Active Voice Sentence: Both are works of art.
# Active Voice Sentence: It’s just that, as artists, Fountain and Foer could not be less alike.
# Active Voice Sentence: Fountain went to Haiti thirty times.
# Active Voice Sentence: Foer went to Trachimbrod just once.
# Active Voice Sentence: “
# Active Voice Sentence: I mean, it was nothing,”
# Active Voice Sentence: Foer said.
# Active Voice Sentence: “I had absolutely no experience there at all.
# Active Voice Sentence: It was just a springboard for my book.
# Passive Voice Sentence: It was like an empty swimming pool that had to be filled up..
# Passive Voice indicators: [('auxpass', 'be')]
# Active Voice Sentence: ”
# Active Voice Sentence: Total time spent getting inspiration for his novel: three days.
#
#
# Active Voice Sentence: Ben Fountain did not make the decision to quit the law and become a writer all by himself.
# Active Voice Sentence: He is married and has a family.
# Active Voice Sentence: He met his wife, Sharon, when they were both in law school at Duke.
# Active Voice Sentence: When he was doing real-estate work at Akin, Gump, she was on the partner track in the tax practice at Thompson & Knight.
# Active Voice Sentence: The two actually worked in the same building in downtown Dallas.
# Passive Voice Sentence: They got married in 1985, and had a son in April of 1987..
# Passive Voice indicators: [('nsubjpass', 'They'), ('auxpass', 'got')]
# Active Voice Sentence: Sharie, as Fountain calls her, took four months of maternity leave before returning to work.
# Active Voice Sentence: She made partner by the end of that year.
#
#
# Active Voice Sentence: “
# Active Voice Sentence: We had our son in a day care downtown,” she recalls.
# Active Voice Sentence: “We would drive in together, one of us would take him to day care, the other one would go to work.
# Active Voice Sentence: One of us would pick him up, and then, somewhere around eight o’clock at night, we would have him bathed, in bed, and then we hadn’t even eaten yet, and we’d be looking at each other, going, ‘
# Active Voice Sentence: This is just the beginning.
# Active Voice Sentence: ’
# Active Voice Sentence: “ She made a face.
# Active Voice Sentence: “
# Active Voice Sentence: That went on for maybe a month or two, and Ben’s like, ‘
# Active Voice Sentence: I don’t know how people do this.
# Active Voice Sentence: ’ We both agreed that continuing at that pace was probably going to make us all miserable.
# Active Voice Sentence: Ben said to me, ‘Do you want to stay home?’
# Passive Voice Sentence: Well, I was pretty happy in my job, and he wasn’t, so as far as I was concerned it didn’t make any sense for me to stay home..
# Passive Voice indicators: [('nsubjpass', 'I'), ('auxpass', 'was')]
# Active Voice Sentence: And I didn’t have anything besides practicing law that I really wanted to do, and he did.
# Active Voice Sentence: So I said, ‘Look, can we do this in a way that we can still have some day care and so you can write?’
# Active Voice Sentence: And so we did that.
# Active Voice Sentence: ”
#
# Ben could start writing at seven-thirty in the morning because Sharie took their son to day care.
# Active Voice Sentence: He stopped working in the afternoon because that was when he had to pick him up, and then he did the shopping and the household chores.
# Active Voice Sentence: In 1989, they had a second child, a daughter.
# Active Voice Sentence: Fountain was a full-fledged North Dallas stay-at-home dad.
#
#
# Active Voice Sentence: “
# Active Voice Sentence: When Ben first did this, we talked about the fact that it might not work, and we talked about, generally, ‘
# Active Voice Sentence: When will we know that it really isn’t working?’ and I’d say, ‘
# Active Voice Sentence: Well, give it ten years,’ “
# Active Voice Sentence: Sharie recalled.
# Active Voice Sentence: To her, ten years didn’t seem unreasonable.
# Active Voice Sentence: “
# Active Voice Sentence: It takes a while to decide whether you like something or not,” she says.
# Active Voice Sentence: And when ten years became twelve and then fourteen and then sixteen, and the kids were off in high school, she stood by him, because, even during that long stretch when Ben had nothing published at all, she was confident that he was getting better.
# Active Voice Sentence: She was fine with the trips to Haiti, too.
# Active Voice Sentence: “
# Active Voice Sentence: I can’t
# Active Voice Sentence: imagine writing a novel about a place you haven’t at least tried to visit,” she says.
# Active Voice Sentence: She even went with him once, and on the way into town from the airport there were people burning tires in the middle of the road.
#
#
# Active Voice Sentence: “
# Active Voice Sentence: I was making pretty decent money, and we didn’t need two incomes,” Sharie went on.
# Active Voice Sentence: She has a calm, unflappable quality about her.
# Active Voice Sentence: “
# Active Voice Sentence: I mean, it would have been nice, but we could live on one.
# Active Voice Sentence: ”
#
#
# Active Voice Sentence: Sharie was Ben’s wife.
# Active Voice Sentence: But she was also—to borrow a term from long ago—his patron.
# Passive Voice Sentence: That word has a condescending edge to it today, because we think it far more appropriate for artists (and everyone else for that matter) to be supported by the marketplace..
# Passive Voice indicators: [('nsubjpass', 'everyone'), ('auxpass', 'be')]
# Active Voice Sentence: But the marketplace works only for people like Jonathan Safran Foer, whose art emerges, fully realized, at the beginning of their career, or Picasso, whose talent was so blindingly obvious that an art dealer offered him a hundred-and-fifty-franc-a-month stipend the minute he got to Paris, at age twenty.
# Active Voice Sentence: If you are the type of creative mind that starts without a plan, and has to experiment and learn by doing, you need someone to see you through the long and difficult time it takes for your art to reach its true level.
#
#
# Active Voice Sentence: This is what is so instructive about any biography of Cézanne.
# Active Voice Sentence: Accounts of his life start out being about Cézanne, and then quickly turn into the story of Cézanne’s circle.
# Active Voice Sentence: First and foremost is always his best friend from childhood, the writer Émile Zola, who convinces the awkward misfit from the provinces to come to Paris, and who serves as his guardian and protector and coach through the long, lean years.
#
#
# Active Voice Sentence: Here is Zola, already in Paris, in a letter to the young Cézanne back in Provence.
# Active Voice Sentence: Note the tone, more paternal than fraternal:
#
# You ask me an odd question.
# Active Voice Sentence: Of course one can work here, as anywhere else, if one has the will.
# Active Voice Sentence: Paris offers, further, an advantage you can’t find elsewhere: the museums in which you can study the old masters from 11 to 4.
# Active Voice Sentence: This is how you must divide your time.
# Active Voice Sentence: From 6 to 11 you go to a studio to paint from a live model; you have lunch, then from 12 to 4 you copy, in the Louvre or the Luxembourg, whatever masterpiece you like.
# Active Voice Sentence: That will make up nine hours of work.
# Active Voice Sentence: I think that ought to be enough.
#
#
#
# Active Voice Sentence: Zola goes on, detailing exactly how Cézanne could manage financially on a monthly stipend of a hundred and twenty-five francs:
#
#  I’ll reckon out for you what you should spend.
# Active Voice Sentence: A room at 20 francs a month; lunch at 18 sous and dinner at 22, which makes two francs a day, or 60 francs a month. . .
# Active Voice Sentence: .
# Active Voice Sentence: Then you have the studio to pay for: the Atelier Suisse, one of the least expensive, charges, I think, 10 francs.
# Active Voice Sentence: Add 10 francs for canvas, brushes, colors; that makes 100.
# Active Voice Sentence: So you’ll have 25 francs left for laundry, light, the thousand little needs that turn up.
#
#
#
# Active Voice Sentence: Camille Pissarro was the next critical figure in Cézanne’s life.
# Active Voice Sentence: It was Pissarro who took Cézanne under his wing and taught him how to be a painter.
# Active Voice Sentence: For years, there would be periods in which they went off into the country and worked side by side.
#
#
# Active Voice Sentence: Then there was Ambrose Vollard, the sponsor of Cézanne’s first one-man show, at the age of fifty-six.
# Active Voice Sentence: At the urging of Pissarro, Renoir, Degas, and Monet, Vollard hunted down Cézanne in Aix.
# Passive Voice Sentence: He spotted a still-life in a tree, where it had been flung by Cézanne in disgust..
# Passive Voice indicators: [('nsubjpass', 'it'), ('auxpass', 'been')]
# Active Voice Sentence: He poked around the town, putting the word out that he was in the market for Cézanne’s canvases.
# Active Voice Sentence: In “
# Active Voice Sentence: Lost Earth: A Life of Cézanne,”
# Active Voice Sentence: the biographer Philip Callow writes about what happened next:
#
#
# Active Voice Sentence: Before long someone appeared at his hotel with an object wrapped in a cloth.
# Active Voice Sentence: He sold the picture for 150 francs, which inspired him to trot back to his house with the dealer to inspect several more magnificent Cézannes.
# Passive Voice Sentence: Vollard paid a thousand francs for the job lot, then on the way out was nearly hit on the head by a canvas that had been overlooked, dropped out the window by the man’s wife..
# Passive Voice indicators: [('auxpass', 'was'), ('nsubjpass', 'that'), ('auxpass', 'been')]
# Active Voice Sentence: All the pictures had been gathering dust, half buried in a pile of junk in the attic.
#
#
#
# Active Voice Sentence: All this came before Vollard agreed to sit a hundred and fifty times, from eight in the morning to eleven-thirty, without a break, for a picture that Cézanne disgustedly abandoned.
# Active Voice Sentence: Once, Vollard recounted in his memoir, he fell asleep, and toppled off the makeshift platform.
# Active Voice Sentence: Cézanne berated him, incensed: “
# Active Voice Sentence: Does an apple move?”
# Passive Voice Sentence: This is called friendship.
#
# .
# Passive Voice indicators: [('nsubjpass', 'This'), ('auxpass', 'is')]
# Active Voice Sentence: Finally, there was Cézanne’s father, the banker Louis-Auguste.
# Active Voice Sentence: From the time Cézanne first left Aix, at the age of twenty-two, Louis-Auguste paid his bills, even when Cézanne gave every indication of being nothing more than a failed dilettante.
# Active Voice Sentence: But for Zola, Cézanne would have remained an unhappy banker’s son in Provence; but for Pissarro, he would never have learned how to paint; but for Vollard (at the urging of Pissarro, Renoir, Degas, and Monet), his canvases would have rotted away in some attic; and, but for his father, Cézanne’s long apprenticeship would have been a financial impossibility.
# Active Voice Sentence: That is an extraordinary list of patrons.
# Active Voice Sentence: The first three—Zola, Pissarro, and Vollard—would have been famous even if Cézanne never existed, and the fourth was an unusually gifted entrepreneur who left Cézanne four hundred thousand francs when he died.
# Active Voice Sentence: Cézanne didn’t just have help.
# Active Voice Sentence: He had a dream team in his corner.
#
#
# Active Voice Sentence: This is the final lesson of the late bloomer: his or her success is highly contingent on the efforts of others.
# Active Voice Sentence: In biographies of Cézanne, Louis-Auguste invariably comes across as a kind of grumpy philistine, who didn’t appreciate his son’s genius.
# Active Voice Sentence: But Louis-Auguste didn’t have to support Cézanne all those years.
# Active Voice Sentence: He would have been within his rights to make his son get a real job, just as Sharie might well have said no to her husband’s repeated trips to the chaos of Haiti.
# Active Voice Sentence: She could have argued that she had some right to the life style of her profession and status—that she deserved to drive a BMW, which is what power couples in North Dallas drive, instead of a Honda Accord, which is what she settled for.
#
#
# Active Voice Sentence: But she believed in her husband’s art, or perhaps, more simply, she believed in her husband, the same way Zola and Pissarro and Vollard and—in his own, querulous way—Louis-Auguste must have believed in Cézanne.
# Active Voice Sentence: Late bloomers’ stories are invariably love stories, and this may be why we have such difficulty with them.
# Active Voice Sentence: We’d like to think that mundane matters like loyalty, steadfastness, and the willingness to keep writing checks to support what looks like failure have nothing to do with something as rarefied as genius.
# Active Voice Sentence: But sometimes genius is anything but rarefied; sometimes it’s just the thing that emerges after twenty years of working at your kitchen table.
#
#
# Active Voice Sentence: “Sharie never once brought up money, not once—never,”
# Active Voice Sentence: Fountain said.
# Active Voice Sentence: She was sitting next to him, and he looked at her in a way that made it plain that he understood how much of the credit for “Brief Encounters” belonged to his wife.
# Active Voice Sentence: His eyes welled up with tears.
# Active Voice Sentence: “I never felt any pressure from her,” he said.
# Active Voice Sentence: “
# Active Voice Sentence: Not even covert, not even implied.”
#
# The percentage of passive sentences in this article is 7.74%
# 7.74
