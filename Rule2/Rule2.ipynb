# %% [markdown]
# # Rule 2: Never use a long word where a short word will do
#
# We are going to take a loose interpretation of this. Instead of word length, we will use both the number of syllables and the order of where it appears in order in a frequency distribution of words. If we just did number of syllables, we would, for example, always replace the word `therefore` with `thus`, which is not in the spirit of the problem.
#
# So let's get cracking on this score!

# %%
import math
import nltk
import pprint as pp
import spacy
import sys
import time

from google_ngram_downloader import readline_google_store
from nltk.corpus import cmudict
from nltk.probability import FreqDist

# %%
nlp = spacy.load('en')
syllable_dict = cmudict.dict()

# %%
# This code was directly copied from Rule #5
# We use it to minimize the words we need to check for because it's a computationally heavy task

def strip_non_words(tokenized_text):
    return [token for token in tokenized_text if token.is_alpha==True]

# Takes in a bag of words and spits out that same bag of words but without the proper nouns
def strip_proper_nouns(tokenized_text):
    return [token for token in tokenized_text if token.tag_ != 'NNP' and token.tag_ != 'NNPS']

# Takes in a bag of words and removes any of them that are in the top n most common words
def strip_most_common_words(tokenized_text, n_most_common=10000):
    # Build the list of most common words
    most_common_words = []
    google_most_common_words_path = sys.path[1] + '/../Texts/google-10000-english-usa.txt'
    with open(google_most_common_words_path, 'r') as f:
        for i in range(n_most_common):
            most_common_words.append(f.readline().strip())
    # Remove anything in the n most common words
    return [token for token in tokenized_text if token.text.lower() not in most_common_words]

def strip_non_jargon_words(tokenized_text):
    text_no_proper_nouns = strip_proper_nouns(tokenized_text)
    text_no_non_words = strip_non_words(text_no_proper_nouns)
    text_no_common_words = strip_most_common_words(text_no_non_words)
    return text_no_common_words

# %%
# This number comes from Google's blog
# https://research.googleblog.com/2006/08/all-our-n-gram-are-belong-to-you.html

# TODO: If there's time, confirm this number
NGRAM_TOKEN_COUNT = 1024908267229

# Shout out to Quora for this snippet of code
# https://www.quora.com/Is-there-any-Google-Ngram-API-for-Python

def find_google_ngrams_word_count(word, time_function=False, verbose=False):
    if time_function == True:
        time1 = time.time()

    count = 2 # Set this to a minimum of 2 so we don't get a divide by zero error
    # TODO: Consider how we want to deal with capitalization
    fname, url, records = next(readline_google_store(ngram_len=1, indices=word[0]))
    # If we use the verbose settings, occaisionally print out the record
    verbosity_count = 10000000
    i = 0
    try:
        record = next(records)
        while record.ngram != word:
            record = next(records)
            if verbose == True and i%verbosity_count == 0:
                print(record)
            i += 1
        while record.ngram == word:
            count += record.match_count
            if verbose == True:
                print(record)
            record = next(records)
    except StopIteration:
        pass
    # Default to 1 so our program doesn't crash
    if count == 0:
        count = 1
    if time_function == True:
        time2 = time.time()
    print('Total seconds for ' + word + ': ' + str(int((time2-time1))))
    return count

def find_frequency_score(word):
    unigram_count = find_google_ngrams_word_count(word, time_function=True)
    percent_occurrence = unigram_count/NGRAM_TOKEN_COUNT
    # Get the log of the frequency to make our number manageable
    freq_val = math.log(percent_occurrence)
    max_ngram_val = math.log(1/NGRAM_TOKEN_COUNT)
    relative_freq = ((freq_val - max_ngram_val)/(-max_ngram_val))
    return round(relative_freq, 5)

# %%
def syllable_count(word, syllable_dict):
    if word in syllable_dict:
        return len(syllable_dict[word])
    # TODO
    # If it's not in the dictionary count the number of vowels and ignore an e at the end not
    # preceded by another vowel. It's rough, but there will be few cases if any cases in which
    # a word is not in the CMU dictionary but in WordNet
    return 1

def readability_for_word(word, syllable_dict):
    syllables = syllable_count(word, syllable_dict)
    freq_score = find_frequency_score(word)
    return (word, syllables, freq_score)
    
example_text = "Sometimes she wears glasses. Other times, she wears spectacles. "
tokenized_text = nlp(example_text)
# Strip out common words and proper nouns for optimization's sake
stripped_text = strip_non_jargon_words(tokenized_text)
pp.pprint(stripped_text)
scored_text = [readability_for_word(token.text.lower(), syllable_dict) for token in stripped_text if token.is_alpha]
pp.pprint(scored_text)
# Out:
# [wears, wears, spectacles]
# Record(ngram="W'ald_NOUN", year=1899, match_count=1, volume_count=1)
# Record(ngram='Wandsbek_NOUN', year=1983, match_count=28, volume_count=14)
# Record(ngram='WELBY', year=1919, match_count=1, volume_count=1)
# Record(ngram='wears', year=1520, match_count=1, volume_count=1)
# Record(ngram='wears', year=1575, match_count=1, volume_count=1)
# Record(ngram='wears', year=1581, match_count=2, volume_count=2)
# Record(ngram='wears', year=1587, match_count=2, volume_count=2)
# Record(ngram='wears', year=1590, match_count=8, volume_count=2)
# Record(ngram='wears', year=1620, match_count=3, volume_count=1)
# Record(ngram='wears', year=1637, match_count=3, volume_count=1)
# Record(ngram='wears', year=1643, match_count=1, volume_count=1)
# Record(ngram='wears', year=1645, match_count=1, volume_count=1)
# Record(ngram='wears', year=1647, match_count=1, volume_count=1)
# Record(ngram='wears', year=1650, match_count=1, volume_count=1)
# Record(ngram='wears', year=1651, match_count=1, volume_count=1)
# Record(ngram='wears', year=1653, match_count=4, volume_count=4)
# Record(ngram='wears', year=1654, match_count=1, volume_count=1)
# Record(ngram='wears', year=1656, match_count=1, volume_count=1)
# Record(ngram='wears', year=1667, match_count=3, volume_count=1)
# Record(ngram='wears', year=1673, match_count=4, volume_count=3)
# Record(ngram='wears', year=1675, match_count=6, volume_count=5)
# Record(ngram='wears', year=1676, match_count=2, volume_count=2)
# Record(ngram='wears', year=1677, match_count=7, volume_count=5)
# Record(ngram='wears', year=1678, match_count=8, volume_count=6)
# Record(ngram='wears', year=1679, match_count=3, volume_count=1)
# Record(ngram='wears', year=1680, match_count=5, volume_count=3)
# Record(ngram='wears', year=1681, match_count=11, volume_count=6)
# Record(ngram='wears', year=1682, match_count=2, volume_count=2)
# Record(ngram='wears', year=1683, match_count=8, volume_count=6)
# Record(ngram='wears', year=1684, match_count=6, volume_count=5)
# Record(ngram='wears', year=1685, match_count=11, volume_count=5)
# Record(ngram='wears', year=1686, match_count=6, volume_count=4)
# Record(ngram='wears', year=1687, match_count=1, volume_count=1)
# Record(ngram='wears', year=1688, match_count=8, volume_count=6)
# Record(ngram='wears', year=1689, match_count=4, volume_count=2)
# Record(ngram='wears', year=1690, match_count=5, volume_count=4)
# Record(ngram='wears', year=1692, match_count=2, volume_count=2)
# Record(ngram='wears', year=1693, match_count=6, volume_count=4)
# Record(ngram='wears', year=1694, match_count=4, volume_count=4)
# Record(ngram='wears', year=1695, match_count=2, volume_count=2)
# Record(ngram='wears', year=1696, match_count=5, volume_count=2)
# Record(ngram='wears', year=1697, match_count=1, volume_count=1)
# Record(ngram='wears', year=1698, match_count=20, volume_count=9)
# Record(ngram='wears', year=1699, match_count=9, volume_count=7)
# Record(ngram='wears', year=1700, match_count=18, volume_count=13)
# Record(ngram='wears', year=1701, match_count=12, volume_count=9)
# Record(ngram='wears', year=1702, match_count=16, volume_count=12)
# Record(ngram='wears', year=1703, match_count=33, volume_count=14)
# Record(ngram='wears', year=1704, match_count=45, volume_count=14)
# Record(ngram='wears', year=1705, match_count=13, volume_count=11)
# Record(ngram='wears', year=1706, match_count=42, volume_count=16)
# Record(ngram='wears', year=1707, match_count=32, volume_count=18)
# Record(ngram='wears', year=1708, match_count=26, volume_count=13)
# Record(ngram='wears', year=1709, match_count=30, volume_count=14)
# Record(ngram='wears', year=1710, match_count=20, volume_count=14)
# Record(ngram='wears', year=1711, match_count=22, volume_count=14)
# Record(ngram='wears', year=1712, match_count=8, volume_count=5)
# Record(ngram='wears', year=1713, match_count=31, volume_count=14)
# Record(ngram='wears', year=1714, match_count=20, volume_count=16)
# Record(ngram='wears', year=1715, match_count=26, volume_count=22)
# Record(ngram='wears', year=1716, match_count=16, volume_count=13)
# Record(ngram='wears', year=1717, match_count=50, volume_count=17)
# Record(ngram='wears', year=1718, match_count=21, volume_count=9)
# Record(ngram='wears', year=1719, match_count=19, volume_count=8)
# Record(ngram='wears', year=1720, match_count=36, volume_count=25)
# Record(ngram='wears', year=1721, match_count=21, volume_count=13)
# Record(ngram='wears', year=1722, match_count=65, volume_count=22)
# Record(ngram='wears', year=1723, match_count=58, volume_count=20)
# Record(ngram='wears', year=1724, match_count=29, volume_count=18)
# Record(ngram='wears', year=1725, match_count=178, volume_count=27)
# Record(ngram='wears', year=1726, match_count=39, volume_count=18)
# Record(ngram='wears', year=1727, match_count=38, volume_count=24)
# Record(ngram='wears', year=1728, match_count=51, volume_count=25)
# Record(ngram='wears', year=1729, match_count=54, volume_count=24)
# Record(ngram='wears', year=1730, match_count=43, volume_count=19)
# Record(ngram='wears', year=1731, match_count=36, volume_count=19)
# Record(ngram='wears', year=1732, match_count=40, volume_count=28)
# Record(ngram='wears', year=1733, match_count=30, volume_count=13)
# Record(ngram='wears', year=1734, match_count=43, volume_count=26)
# Record(ngram='wears', year=1735, match_count=37, volume_count=18)
# Record(ngram='wears', year=1736, match_count=40, volume_count=26)
# Record(ngram='wears', year=1737, match_count=66, volume_count=34)
# Record(ngram='wears', year=1738, match_count=30, volume_count=21)
# Record(ngram='wears', year=1739, match_count=46, volume_count=23)
# Record(ngram='wears', year=1740, match_count=37, volume_count=18)
# Record(ngram='wears', year=1741, match_count=37, volume_count=22)
# Record(ngram='wears', year=1742, match_count=47, volume_count=28)
# Record(ngram='wears', year=1743, match_count=71, volume_count=29)
# Record(ngram='wears', year=1744, match_count=69, volume_count=35)
# Record(ngram='wears', year=1745, match_count=48, volume_count=23)
# Record(ngram='wears', year=1746, match_count=40, volume_count=20)
# Record(ngram='wears', year=1747, match_count=65, volume_count=39)
# Record(ngram='wears', year=1748, match_count=56, volume_count=33)
# Record(ngram='wears', year=1749, match_count=44, volume_count=31)
# Record(ngram='wears', year=1750, match_count=74, volume_count=35)
# Record(ngram='wears', year=1751, match_count=75, volume_count=43)
# Record(ngram='wears', year=1752, match_count=42, volume_count=32)
# Record(ngram='wears', year=1753, match_count=61, volume_count=41)
# Record(ngram='wears', year=1754, match_count=133, volume_count=59)
# Record(ngram='wears', year=1755, match_count=95, volume_count=55)
# Record(ngram='wears', year=1756, match_count=37, volume_count=27)
# Record(ngram='wears', year=1757, match_count=73, volume_count=39)
# Record(ngram='wears', year=1758, match_count=52, volume_count=36)
# Record(ngram='wears', year=1759, match_count=104, volume_count=40)
# Record(ngram='wears', year=1760, match_count=77, volume_count=43)
# Record(ngram='wears', year=1761, match_count=86, volume_count=45)
# Record(ngram='wears', year=1762, match_count=67, volume_count=42)
# Record(ngram='wears', year=1763, match_count=78, volume_count=45)
# Record(ngram='wears', year=1764, match_count=76, volume_count=51)
# Record(ngram='wears', year=1765, match_count=102, volume_count=59)
# Record(ngram='wears', year=1766, match_count=131, volume_count=75)
# Record(ngram='wears', year=1767, match_count=118, volume_count=70)
# Record(ngram='wears', year=1768, match_count=176, volume_count=99)
# Record(ngram='wears', year=1769, match_count=104, volume_count=56)
# Record(ngram='wears', year=1770, match_count=136, volume_count=69)
# Record(ngram='wears', year=1771, match_count=57, volume_count=44)
# Record(ngram='wears', year=1772, match_count=116, volume_count=72)
# Record(ngram='wears', year=1773, match_count=59, volume_count=38)
# Record(ngram='wears', year=1774, match_count=94, volume_count=65)
# Record(ngram='wears', year=1775, match_count=98, volume_count=67)
# Record(ngram='wears', year=1776, match_count=148, volume_count=92)
# Record(ngram='wears', year=1777, match_count=152, volume_count=83)
# Record(ngram='wears', year=1778, match_count=111, volume_count=56)
# Record(ngram='wears', year=1779, match_count=122, volume_count=72)
# Record(ngram='wears', year=1780, match_count=112, volume_count=70)
# Record(ngram='wears', year=1781, match_count=100, volume_count=61)
# Record(ngram='wears', year=1782, match_count=97, volume_count=60)
# Record(ngram='wears', year=1783, match_count=103, volume_count=62)
# Record(ngram='wears', year=1784, match_count=172, volume_count=81)
# Record(ngram='wears', year=1785, match_count=136, volume_count=75)
# Record(ngram='wears', year=1786, match_count=137, volume_count=74)
# Record(ngram='wears', year=1787, match_count=197, volume_count=125)
# Record(ngram='wears', year=1788, match_count=238, volume_count=134)
# Record(ngram='wears', year=1789, match_count=150, volume_count=92)
# Record(ngram='wears', year=1790, match_count=189, volume_count=113)
# Record(ngram='wears', year=1791, match_count=218, volume_count=135)
# Record(ngram='wears', year=1792, match_count=281, volume_count=158)
# Record(ngram='wears', year=1793, match_count=213, volume_count=122)
# Record(ngram='wears', year=1794, match_count=259, volume_count=153)
# Record(ngram='wears', year=1795, match_count=193, volume_count=114)
# Record(ngram='wears', year=1796, match_count=237, volume_count=160)
# Record(ngram='wears', year=1797, match_count=278, volume_count=148)
# Record(ngram='wears', year=1798, match_count=246, volume_count=146)
# Record(ngram='wears', year=1799, match_count=296, volume_count=169)
# Record(ngram='wears', year=1800, match_count=458, volume_count=193)
# Record(ngram='wears', year=1801, match_count=590, volume_count=348)
# Record(ngram='wears', year=1802, match_count=447, volume_count=238)
# Record(ngram='wears', year=1803, match_count=593, volume_count=302)
# Record(ngram='wears', year=1804, match_count=529, volume_count=310)
# Record(ngram='wears', year=1805, match_count=640, volume_count=329)
# Record(ngram='wears', year=1806, match_count=753, volume_count=400)
# Record(ngram='wears', year=1807, match_count=681, volume_count=373)
# Record(ngram='wears', year=1808, match_count=864, volume_count=422)
# Record(ngram='wears', year=1809, match_count=751, volume_count=385)
# Record(ngram='wears', year=1810, match_count=691, volume_count=364)
# Record(ngram='wears', year=1811, match_count=1073, volume_count=494)
# Record(ngram='wears', year=1812, match_count=731, volume_count=404)
# Record(ngram='wears', year=1813, match_count=724, volume_count=384)
# Record(ngram='wears', year=1814, match_count=714, volume_count=400)
# Record(ngram='wears', year=1815, match_count=691, volume_count=383)
# Record(ngram='wears', year=1816, match_count=836, volume_count=438)
# Record(ngram='wears', year=1817, match_count=782, volume_count=424)
# Record(ngram='wears', year=1818, match_count=887, volume_count=492)
# Record(ngram='wears', year=1819, match_count=976, volume_count=479)
# Record(ngram='wears', year=1820, match_count=1175, volume_count=626)
# Record(ngram='wears', year=1821, match_count=945, volume_count=480)
# Record(ngram='wears', year=1822, match_count=1304, volume_count=674)
# Record(ngram='wears', year=1823, match_count=1495, volume_count=824)
# Record(ngram='wears', year=1824, match_count=1622, volume_count=880)
# Record(ngram='wears', year=1825, match_count=1843, volume_count=856)
# Record(ngram='wears', year=1826, match_count=1281, volume_count=686)
# Record(ngram='wears', year=1827, match_count=1151, volume_count=647)
# Record(ngram='wears', year=1828, match_count=1379, volume_count=735)
# Record(ngram='wears', year=1829, match_count=1191, volume_count=690)
# Record(ngram='wears', year=1830, match_count=1555, volume_count=862)
# Record(ngram='wears', year=1831, match_count=1389, volume_count=850)
# Record(ngram='wears', year=1832, match_count=1488, volume_count=753)
# Record(ngram='wears', year=1833, match_count=1446, volume_count=841)
# Record(ngram='wears', year=1834, match_count=1490, volume_count=808)
# Record(ngram='wears', year=1835, match_count=1873, volume_count=991)
# Record(ngram='wears', year=1836, match_count=1987, volume_count=1049)
# Record(ngram='wears', year=1837, match_count=1785, volume_count=893)
# Record(ngram='wears', year=1838, match_count=1829, volume_count=927)
# Record(ngram='wears', year=1839, match_count=2185, volume_count=1073)
# Record(ngram='wears', year=1840, match_count=2031, volume_count=1034)
# Record(ngram='wears', year=1841, match_count=2276, volume_count=1031)
# Record(ngram='wears', year=1842, match_count=1806, volume_count=908)
# Record(ngram='wears', year=1843, match_count=1972, volume_count=938)
# Record(ngram='wears', year=1844, match_count=2031, volume_count=1024)
# Record(ngram='wears', year=1845, match_count=2425, volume_count=1186)
# Record(ngram='wears', year=1846, match_count=3043, volume_count=1178)
# Record(ngram='wears', year=1847, match_count=2433, volume_count=1070)
# Record(ngram='wears', year=1848, match_count=2514, volume_count=1201)
# Record(ngram='wears', year=1849, match_count=2497, volume_count=1263)
# Record(ngram='wears', year=1850, match_count=2921, volume_count=1339)
# Record(ngram='wears', year=1851, match_count=3038, volume_count=1418)
# Record(ngram='wears', year=1852, match_count=4223, volume_count=1547)
# Record(ngram='wears', year=1853, match_count=3455, volume_count=1556)
# Record(ngram='wears', year=1854, match_count=3824, volume_count=1764)
# Record(ngram='wears', year=1855, match_count=3050, volume_count=1534)
# Record(ngram='wears', year=1856, match_count=3688, volume_count=1756)
# Record(ngram='wears', year=1857, match_count=3316, volume_count=1521)
# Record(ngram='wears', year=1858, match_count=2680, volume_count=1371)
# Record(ngram='wears', year=1859, match_count=3140, volume_count=1548)
# Record(ngram='wears', year=1860, match_count=3566, volume_count=1743)
# Record(ngram='wears', year=1861, match_count=2526, volume_count=1195)
# Record(ngram='wears', year=1862, match_count=2179, volume_count=1136)
# Record(ngram='wears', year=1863, match_count=2636, volume_count=1137)
# Record(ngram='wears', year=1864, match_count=3138, volume_count=1440)
# Record(ngram='wears', year=1865, match_count=2788, volume_count=1338)
# Record(ngram='wears', year=1866, match_count=3176, volume_count=1448)
# Record(ngram='wears', year=1867, match_count=3114, volume_count=1344)
# Record(ngram='wears', year=1868, match_count=3261, volume_count=1478)
# Record(ngram='wears', year=1869, match_count=3459, volume_count=1587)
# Record(ngram='wears', year=1870, match_count=3684, volume_count=1590)
# Record(ngram='wears', year=1871, match_count=3149, volume_count=1572)
# Record(ngram='wears', year=1872, match_count=4155, volume_count=1578)
# Record(ngram='wears', year=1873, match_count=3845, volume_count=1639)
# Record(ngram='wears', year=1874, match_count=3806, volume_count=1738)
# Record(ngram='wears', year=1875, match_count=3704, volume_count=1766)
# Record(ngram='wears', year=1876, match_count=4272, volume_count=1892)
# Record(ngram='wears', year=1877, match_count=3807, volume_count=1815)
# Record(ngram='wears', year=1878, match_count=4100, volume_count=1769)
# Record(ngram='wears', year=1879, match_count=4044, volume_count=1800)
# Record(ngram='wears', year=1880, match_count=4852, volume_count=2108)
# Record(ngram='wears', year=1881, match_count=4692, volume_count=2212)
# Record(ngram='wears', year=1882, match_count=5299, volume_count=2333)
# Record(ngram='wears', year=1883, match_count=6548, volume_count=2702)
# Record(ngram='wears', year=1884, match_count=5296, volume_count=2425)
# Record(ngram='wears', year=1885, match_count=5731, volume_count=2400)
# Record(ngram='wears', year=1886, match_count=4113, volume_count=1957)
# Record(ngram='wears', year=1887, match_count=5022, volume_count=2417)
# Record(ngram='wears', year=1888, match_count=4630, volume_count=2248)
# Record(ngram='wears', year=1889, match_count=4345, volume_count=2086)
# Record(ngram='wears', year=1890, match_count=4789, volume_count=2299)
# Record(ngram='wears', year=1891, match_count=5911, volume_count=2511)
# Record(ngram='wears', year=1892, match_count=6241, volume_count=2790)
# Record(ngram='wears', year=1893, match_count=5749, volume_count=2671)
# Record(ngram='wears', year=1894, match_count=5894, volume_count=2597)
# Record(ngram='wears', year=1895, match_count=6207, volume_count=2930)
# Record(ngram='wears', year=1896, match_count=7266, volume_count=3227)
# Record(ngram='wears', year=1897, match_count=7069, volume_count=3145)
# Record(ngram='wears', year=1898, match_count=6983, volume_count=3270)
# Record(ngram='wears', year=1899, match_count=8695, volume_count=3860)
# Record(ngram='wears', year=1900, match_count=9338, volume_count=4160)
# Record(ngram='wears', year=1901, match_count=8593, volume_count=3909)
# Record(ngram='wears', year=1902, match_count=8629, volume_count=4090)
# Record(ngram='wears', year=1903, match_count=8988, volume_count=3796)
# Record(ngram='wears', year=1904, match_count=10226, volume_count=4312)
# Record(ngram='wears', year=1905, match_count=8800, volume_count=3905)
# Record(ngram='wears', year=1906, match_count=9453, volume_count=4211)
# Record(ngram='wears', year=1907, match_count=13198, volume_count=4195)
# Record(ngram='wears', year=1908, match_count=8842, volume_count=4237)
# Record(ngram='wears', year=1909, match_count=8328, volume_count=3762)
# Record(ngram='wears', year=1910, match_count=9776, volume_count=4185)
# Record(ngram='wears', year=1911, match_count=8580, volume_count=3963)
# Record(ngram='wears', year=1912, match_count=9855, volume_count=4182)
# Record(ngram='wears', year=1913, match_count=8225, volume_count=3939)
# Record(ngram='wears', year=1914, match_count=12215, volume_count=3969)
# Record(ngram='wears', year=1915, match_count=7225, volume_count=3332)
# Record(ngram='wears', year=1916, match_count=7007, volume_count=3421)
# Record(ngram='wears', year=1917, match_count=7665, volume_count=3597)
# Record(ngram='wears', year=1918, match_count=6522, volume_count=3104)
# Record(ngram='wears', year=1919, match_count=6951, volume_count=3318)
# Record(ngram='wears', year=1920, match_count=7940, volume_count=3924)
# Record(ngram='wears', year=1921, match_count=7130, volume_count=3476)
# Record(ngram='wears', year=1922, match_count=8126, volume_count=3936)
# Record(ngram='wears', year=1923, match_count=8627, volume_count=3547)
# Record(ngram='wears', year=1924, match_count=7445, volume_count=3148)
# Record(ngram='wears', year=1925, match_count=7037, volume_count=3263)
# Record(ngram='wears', year=1926, match_count=6779, volume_count=3000)
# Record(ngram='wears', year=1927, match_count=7512, volume_count=3370)
# Record(ngram='wears', year=1928, match_count=7308, volume_count=3412)
# Record(ngram='wears', year=1929, match_count=7490, volume_count=3361)
# Record(ngram='wears', year=1930, match_count=7657, volume_count=3416)
# Record(ngram='wears', year=1931, match_count=7379, volume_count=3082)
# Record(ngram='wears', year=1932, match_count=5915, volume_count=2672)
# Record(ngram='wears', year=1933, match_count=4863, volume_count=2372)
# Record(ngram='wears', year=1934, match_count=5998, volume_count=2570)
# Record(ngram='wears', year=1935, match_count=6524, volume_count=2925)
# Record(ngram='wears', year=1936, match_count=6566, volume_count=3040)
# Record(ngram='wears', year=1937, match_count=6973, volume_count=3054)
# Record(ngram='wears', year=1938, match_count=7248, volume_count=3106)
# Record(ngram='wears', year=1939, match_count=6950, volume_count=2944)
# Record(ngram='wears', year=1940, match_count=6556, volume_count=2664)
# Record(ngram='wears', year=1941, match_count=5737, volume_count=2650)
# Record(ngram='wears', year=1942, match_count=6159, volume_count=2622)
# Record(ngram='wears', year=1943, match_count=5087, volume_count=2235)
# Record(ngram='wears', year=1944, match_count=4430, volume_count=2058)
# Record(ngram='wears', year=1945, match_count=4652, volume_count=2187)
# Record(ngram='wears', year=1946, match_count=6568, volume_count=2957)
# Record(ngram='wears', year=1947, match_count=7758, volume_count=3497)
# Record(ngram='wears', year=1948, match_count=8851, volume_count=3592)
# Record(ngram='wears', year=1949, match_count=8415, volume_count=3705)
# Record(ngram='wears', year=1950, match_count=8364, volume_count=3650)
# Record(ngram='wears', year=1951, match_count=7762, volume_count=3565)
# Record(ngram='wears', year=1952, match_count=7711, volume_count=3527)
# Record(ngram='wears', year=1953, match_count=8043, volume_count=3616)
# Record(ngram='wears', year=1954, match_count=8217, volume_count=3746)
# Record(ngram='wears', year=1955, match_count=8890, volume_count=3814)
# Record(ngram='wears', year=1956, match_count=9229, volume_count=4018)
# Record(ngram='wears', year=1957, match_count=9206, volume_count=4195)
# Record(ngram='wears', year=1958, match_count=8982, volume_count=4144)
# Record(ngram='wears', year=1959, match_count=9313, volume_count=4325)
# Record(ngram='wears', year=1960, match_count=10543, volume_count=4862)
# Record(ngram='wears', year=1961, match_count=11989, volume_count=5343)
# Record(ngram='wears', year=1962, match_count=12802, volume_count=5782)
# Record(ngram='wears', year=1963, match_count=13305, volume_count=5947)
# Record(ngram='wears', year=1964, match_count=13868, volume_count=6023)
# Record(ngram='wears', year=1965, match_count=14783, volume_count=6537)
# Record(ngram='wears', year=1966, match_count=15107, volume_count=6901)
# Record(ngram='wears', year=1967, match_count=18311, volume_count=7521)
# Record(ngram='wears', year=1968, match_count=19867, volume_count=8353)
# Record(ngram='wears', year=1969, match_count=18889, volume_count=8287)
# Record(ngram='wears', year=1970, match_count=20932, volume_count=8897)
# Record(ngram='wears', year=1971, match_count=18676, volume_count=8490)
# Record(ngram='wears', year=1972, match_count=18893, volume_count=8743)
# Record(ngram='wears', year=1973, match_count=18691, volume_count=8397)
# Record(ngram='wears', year=1974, match_count=18061, volume_count=8156)
# Record(ngram='wears', year=1975, match_count=20172, volume_count=8113)
# Record(ngram='wears', year=1976, match_count=18343, volume_count=8540)
# Record(ngram='wears', year=1977, match_count=20643, volume_count=8908)
# Record(ngram='wears', year=1978, match_count=20502, volume_count=8648)
# Record(ngram='wears', year=1979, match_count=19967, volume_count=8804)
# Record(ngram='wears', year=1980, match_count=21598, volume_count=8953)
# Record(ngram='wears', year=1981, match_count=20233, volume_count=8731)
# Record(ngram='wears', year=1982, match_count=21824, volume_count=9428)
# Record(ngram='wears', year=1983, match_count=22098, volume_count=9387)
# Record(ngram='wears', year=1984, match_count=24581, volume_count=10103)
# Record(ngram='wears', year=1985, match_count=25338, volume_count=10347)
# Record(ngram='wears', year=1986, match_count=25658, volume_count=10980)
# Record(ngram='wears', year=1987, match_count=26772, volume_count=11532)
# Record(ngram='wears', year=1988, match_count=27498, volume_count=12052)
# Record(ngram='wears', year=1989, match_count=30340, volume_count=12787)
# Record(ngram='wears', year=1990, match_count=31317, volume_count=13890)
# Record(ngram='wears', year=1991, match_count=30422, volume_count=13758)
# Record(ngram='wears', year=1992, match_count=34433, volume_count=14966)
# Record(ngram='wears', year=1993, match_count=36724, volume_count=14990)
# Record(ngram='wears', year=1994, match_count=36562, volume_count=16065)
# Record(ngram='wears', year=1995, match_count=39907, volume_count=16886)
# Record(ngram='wears', year=1996, match_count=40836, volume_count=17798)
# Record(ngram='wears', year=1997, match_count=41502, volume_count=18331)
# Record(ngram='wears', year=1998, match_count=44330, volume_count=19423)
# Record(ngram='wears', year=1999, match_count=46747, volume_count=20509)
# Record(ngram='wears', year=2000, match_count=53026, volume_count=23524)
# Record(ngram='wears', year=2001, match_count=55668, volume_count=23947)
# Record(ngram='wears', year=2002, match_count=59766, volume_count=26158)
# Record(ngram='wears', year=2003, match_count=66725, volume_count=29169)
# Record(ngram='wears', year=2004, match_count=73899, volume_count=33482)
# Record(ngram='wears', year=2005, match_count=70862, volume_count=32158)
# Record(ngram='wears', year=2006, match_count=74709, volume_count=33643)
# Record(ngram='wears', year=2007, match_count=81991, volume_count=37508)
# Record(ngram='wears', year=2008, match_count=113143, volume_count=55221)
# Total seconds: 134
# Record(ngram="W'ald_NOUN", year=1899, match_count=1, volume_count=1)
# Record(ngram='Wandsbek_NOUN', year=1983, match_count=28, volume_count=14)
# Record(ngram='WELBY', year=1919, match_count=1, volume_count=1)
# Record(ngram='wears', year=1520, match_count=1, volume_count=1)
# Record(ngram='wears', year=1575, match_count=1, volume_count=1)
# Record(ngram='wears', year=1581, match_count=2, volume_count=2)
# Record(ngram='wears', year=1587, match_count=2, volume_count=2)
# Record(ngram='wears', year=1590, match_count=8, volume_count=2)
# Record(ngram='wears', year=1620, match_count=3, volume_count=1)
# Record(ngram='wears', year=1637, match_count=3, volume_count=1)
# Record(ngram='wears', year=1643, match_count=1, volume_count=1)
# Record(ngram='wears', year=1645, match_count=1, volume_count=1)
# Record(ngram='wears', year=1647, match_count=1, volume_count=1)
# Record(ngram='wears', year=1650, match_count=1, volume_count=1)
# Record(ngram='wears', year=1651, match_count=1, volume_count=1)
# Record(ngram='wears', year=1653, match_count=4, volume_count=4)
# Record(ngram='wears', year=1654, match_count=1, volume_count=1)
# Record(ngram='wears', year=1656, match_count=1, volume_count=1)
# Record(ngram='wears', year=1667, match_count=3, volume_count=1)
# Record(ngram='wears', year=1673, match_count=4, volume_count=3)
# Record(ngram='wears', year=1675, match_count=6, volume_count=5)
# Record(ngram='wears', year=1676, match_count=2, volume_count=2)
# Record(ngram='wears', year=1677, match_count=7, volume_count=5)
# Record(ngram='wears', year=1678, match_count=8, volume_count=6)
# Record(ngram='wears', year=1679, match_count=3, volume_count=1)
# Record(ngram='wears', year=1680, match_count=5, volume_count=3)
# Record(ngram='wears', year=1681, match_count=11, volume_count=6)
# Record(ngram='wears', year=1682, match_count=2, volume_count=2)
# Record(ngram='wears', year=1683, match_count=8, volume_count=6)
# Record(ngram='wears', year=1684, match_count=6, volume_count=5)
# Record(ngram='wears', year=1685, match_count=11, volume_count=5)
# Record(ngram='wears', year=1686, match_count=6, volume_count=4)
# Record(ngram='wears', year=1687, match_count=1, volume_count=1)
# Record(ngram='wears', year=1688, match_count=8, volume_count=6)
# Record(ngram='wears', year=1689, match_count=4, volume_count=2)
# Record(ngram='wears', year=1690, match_count=5, volume_count=4)
# Record(ngram='wears', year=1692, match_count=2, volume_count=2)
# Record(ngram='wears', year=1693, match_count=6, volume_count=4)
# Record(ngram='wears', year=1694, match_count=4, volume_count=4)
# Record(ngram='wears', year=1695, match_count=2, volume_count=2)
# Record(ngram='wears', year=1696, match_count=5, volume_count=2)
# Record(ngram='wears', year=1697, match_count=1, volume_count=1)
# Record(ngram='wears', year=1698, match_count=20, volume_count=9)
# Record(ngram='wears', year=1699, match_count=9, volume_count=7)
# Record(ngram='wears', year=1700, match_count=18, volume_count=13)
# Record(ngram='wears', year=1701, match_count=12, volume_count=9)
# Record(ngram='wears', year=1702, match_count=16, volume_count=12)
# Record(ngram='wears', year=1703, match_count=33, volume_count=14)
# Record(ngram='wears', year=1704, match_count=45, volume_count=14)
# Record(ngram='wears', year=1705, match_count=13, volume_count=11)
# Record(ngram='wears', year=1706, match_count=42, volume_count=16)
# Record(ngram='wears', year=1707, match_count=32, volume_count=18)
# Record(ngram='wears', year=1708, match_count=26, volume_count=13)
# Record(ngram='wears', year=1709, match_count=30, volume_count=14)
# Record(ngram='wears', year=1710, match_count=20, volume_count=14)
# Record(ngram='wears', year=1711, match_count=22, volume_count=14)
# Record(ngram='wears', year=1712, match_count=8, volume_count=5)
# Record(ngram='wears', year=1713, match_count=31, volume_count=14)
# Record(ngram='wears', year=1714, match_count=20, volume_count=16)
# Record(ngram='wears', year=1715, match_count=26, volume_count=22)
# Record(ngram='wears', year=1716, match_count=16, volume_count=13)
# Record(ngram='wears', year=1717, match_count=50, volume_count=17)
# Record(ngram='wears', year=1718, match_count=21, volume_count=9)
# Record(ngram='wears', year=1719, match_count=19, volume_count=8)
# Record(ngram='wears', year=1720, match_count=36, volume_count=25)
# Record(ngram='wears', year=1721, match_count=21, volume_count=13)
# Record(ngram='wears', year=1722, match_count=65, volume_count=22)
# Record(ngram='wears', year=1723, match_count=58, volume_count=20)
# Record(ngram='wears', year=1724, match_count=29, volume_count=18)
# Record(ngram='wears', year=1725, match_count=178, volume_count=27)
# Record(ngram='wears', year=1726, match_count=39, volume_count=18)
# Record(ngram='wears', year=1727, match_count=38, volume_count=24)
# Record(ngram='wears', year=1728, match_count=51, volume_count=25)
# Record(ngram='wears', year=1729, match_count=54, volume_count=24)
# Record(ngram='wears', year=1730, match_count=43, volume_count=19)
# Record(ngram='wears', year=1731, match_count=36, volume_count=19)
# Record(ngram='wears', year=1732, match_count=40, volume_count=28)
# Record(ngram='wears', year=1733, match_count=30, volume_count=13)
# Record(ngram='wears', year=1734, match_count=43, volume_count=26)
# Record(ngram='wears', year=1735, match_count=37, volume_count=18)
# Record(ngram='wears', year=1736, match_count=40, volume_count=26)
# Record(ngram='wears', year=1737, match_count=66, volume_count=34)
# Record(ngram='wears', year=1738, match_count=30, volume_count=21)
# Record(ngram='wears', year=1739, match_count=46, volume_count=23)
# Record(ngram='wears', year=1740, match_count=37, volume_count=18)
# Record(ngram='wears', year=1741, match_count=37, volume_count=22)
# Record(ngram='wears', year=1742, match_count=47, volume_count=28)
# Record(ngram='wears', year=1743, match_count=71, volume_count=29)
# Record(ngram='wears', year=1744, match_count=69, volume_count=35)
# Record(ngram='wears', year=1745, match_count=48, volume_count=23)
# Record(ngram='wears', year=1746, match_count=40, volume_count=20)
# Record(ngram='wears', year=1747, match_count=65, volume_count=39)
# Record(ngram='wears', year=1748, match_count=56, volume_count=33)
# Record(ngram='wears', year=1749, match_count=44, volume_count=31)
# Record(ngram='wears', year=1750, match_count=74, volume_count=35)
# Record(ngram='wears', year=1751, match_count=75, volume_count=43)
# Record(ngram='wears', year=1752, match_count=42, volume_count=32)
# Record(ngram='wears', year=1753, match_count=61, volume_count=41)
# Record(ngram='wears', year=1754, match_count=133, volume_count=59)
# Record(ngram='wears', year=1755, match_count=95, volume_count=55)
# Record(ngram='wears', year=1756, match_count=37, volume_count=27)
# Record(ngram='wears', year=1757, match_count=73, volume_count=39)
# Record(ngram='wears', year=1758, match_count=52, volume_count=36)
# Record(ngram='wears', year=1759, match_count=104, volume_count=40)
# Record(ngram='wears', year=1760, match_count=77, volume_count=43)
# Record(ngram='wears', year=1761, match_count=86, volume_count=45)
# Record(ngram='wears', year=1762, match_count=67, volume_count=42)
# Record(ngram='wears', year=1763, match_count=78, volume_count=45)
# Record(ngram='wears', year=1764, match_count=76, volume_count=51)
# Record(ngram='wears', year=1765, match_count=102, volume_count=59)
# Record(ngram='wears', year=1766, match_count=131, volume_count=75)
# Record(ngram='wears', year=1767, match_count=118, volume_count=70)
# Record(ngram='wears', year=1768, match_count=176, volume_count=99)
# Record(ngram='wears', year=1769, match_count=104, volume_count=56)
# Record(ngram='wears', year=1770, match_count=136, volume_count=69)
# Record(ngram='wears', year=1771, match_count=57, volume_count=44)
# Record(ngram='wears', year=1772, match_count=116, volume_count=72)
# Record(ngram='wears', year=1773, match_count=59, volume_count=38)
# Record(ngram='wears', year=1774, match_count=94, volume_count=65)
# Record(ngram='wears', year=1775, match_count=98, volume_count=67)
# Record(ngram='wears', year=1776, match_count=148, volume_count=92)
# Record(ngram='wears', year=1777, match_count=152, volume_count=83)
# Record(ngram='wears', year=1778, match_count=111, volume_count=56)
# Record(ngram='wears', year=1779, match_count=122, volume_count=72)
# Record(ngram='wears', year=1780, match_count=112, volume_count=70)
# Record(ngram='wears', year=1781, match_count=100, volume_count=61)
# Record(ngram='wears', year=1782, match_count=97, volume_count=60)
# Record(ngram='wears', year=1783, match_count=103, volume_count=62)
# Record(ngram='wears', year=1784, match_count=172, volume_count=81)
# Record(ngram='wears', year=1785, match_count=136, volume_count=75)
# Record(ngram='wears', year=1786, match_count=137, volume_count=74)
# Record(ngram='wears', year=1787, match_count=197, volume_count=125)
# Record(ngram='wears', year=1788, match_count=238, volume_count=134)
# Record(ngram='wears', year=1789, match_count=150, volume_count=92)
# Record(ngram='wears', year=1790, match_count=189, volume_count=113)
# Record(ngram='wears', year=1791, match_count=218, volume_count=135)
# Record(ngram='wears', year=1792, match_count=281, volume_count=158)
# Record(ngram='wears', year=1793, match_count=213, volume_count=122)
# Record(ngram='wears', year=1794, match_count=259, volume_count=153)
# Record(ngram='wears', year=1795, match_count=193, volume_count=114)
# Record(ngram='wears', year=1796, match_count=237, volume_count=160)
# Record(ngram='wears', year=1797, match_count=278, volume_count=148)
# Record(ngram='wears', year=1798, match_count=246, volume_count=146)
# Record(ngram='wears', year=1799, match_count=296, volume_count=169)
# Record(ngram='wears', year=1800, match_count=458, volume_count=193)
# Record(ngram='wears', year=1801, match_count=590, volume_count=348)
# Record(ngram='wears', year=1802, match_count=447, volume_count=238)
# Record(ngram='wears', year=1803, match_count=593, volume_count=302)
# Record(ngram='wears', year=1804, match_count=529, volume_count=310)
# Record(ngram='wears', year=1805, match_count=640, volume_count=329)
# Record(ngram='wears', year=1806, match_count=753, volume_count=400)
# Record(ngram='wears', year=1807, match_count=681, volume_count=373)
# Record(ngram='wears', year=1808, match_count=864, volume_count=422)
# Record(ngram='wears', year=1809, match_count=751, volume_count=385)
# Record(ngram='wears', year=1810, match_count=691, volume_count=364)
# Record(ngram='wears', year=1811, match_count=1073, volume_count=494)
# Record(ngram='wears', year=1812, match_count=731, volume_count=404)
# Record(ngram='wears', year=1813, match_count=724, volume_count=384)
# Record(ngram='wears', year=1814, match_count=714, volume_count=400)
# Record(ngram='wears', year=1815, match_count=691, volume_count=383)
# Record(ngram='wears', year=1816, match_count=836, volume_count=438)
# Record(ngram='wears', year=1817, match_count=782, volume_count=424)
# Record(ngram='wears', year=1818, match_count=887, volume_count=492)
# Record(ngram='wears', year=1819, match_count=976, volume_count=479)
# Record(ngram='wears', year=1820, match_count=1175, volume_count=626)
# Record(ngram='wears', year=1821, match_count=945, volume_count=480)
# Record(ngram='wears', year=1822, match_count=1304, volume_count=674)
# Record(ngram='wears', year=1823, match_count=1495, volume_count=824)
# Record(ngram='wears', year=1824, match_count=1622, volume_count=880)
# Record(ngram='wears', year=1825, match_count=1843, volume_count=856)
# Record(ngram='wears', year=1826, match_count=1281, volume_count=686)
# Record(ngram='wears', year=1827, match_count=1151, volume_count=647)
# Record(ngram='wears', year=1828, match_count=1379, volume_count=735)
# Record(ngram='wears', year=1829, match_count=1191, volume_count=690)
# Record(ngram='wears', year=1830, match_count=1555, volume_count=862)
# Record(ngram='wears', year=1831, match_count=1389, volume_count=850)
# Record(ngram='wears', year=1832, match_count=1488, volume_count=753)
# Record(ngram='wears', year=1833, match_count=1446, volume_count=841)
# Record(ngram='wears', year=1834, match_count=1490, volume_count=808)
# Record(ngram='wears', year=1835, match_count=1873, volume_count=991)
# Record(ngram='wears', year=1836, match_count=1987, volume_count=1049)
# Record(ngram='wears', year=1837, match_count=1785, volume_count=893)
# Record(ngram='wears', year=1838, match_count=1829, volume_count=927)
# Record(ngram='wears', year=1839, match_count=2185, volume_count=1073)
# Record(ngram='wears', year=1840, match_count=2031, volume_count=1034)
# Record(ngram='wears', year=1841, match_count=2276, volume_count=1031)
# Record(ngram='wears', year=1842, match_count=1806, volume_count=908)
# Record(ngram='wears', year=1843, match_count=1972, volume_count=938)
# Record(ngram='wears', year=1844, match_count=2031, volume_count=1024)
# Record(ngram='wears', year=1845, match_count=2425, volume_count=1186)
# Record(ngram='wears', year=1846, match_count=3043, volume_count=1178)
# Record(ngram='wears', year=1847, match_count=2433, volume_count=1070)
# Record(ngram='wears', year=1848, match_count=2514, volume_count=1201)
# Record(ngram='wears', year=1849, match_count=2497, volume_count=1263)
# Record(ngram='wears', year=1850, match_count=2921, volume_count=1339)
# Record(ngram='wears', year=1851, match_count=3038, volume_count=1418)
# Record(ngram='wears', year=1852, match_count=4223, volume_count=1547)
# Record(ngram='wears', year=1853, match_count=3455, volume_count=1556)
# Record(ngram='wears', year=1854, match_count=3824, volume_count=1764)
# Record(ngram='wears', year=1855, match_count=3050, volume_count=1534)
# Record(ngram='wears', year=1856, match_count=3688, volume_count=1756)
# Record(ngram='wears', year=1857, match_count=3316, volume_count=1521)
# Record(ngram='wears', year=1858, match_count=2680, volume_count=1371)
# Record(ngram='wears', year=1859, match_count=3140, volume_count=1548)
# Record(ngram='wears', year=1860, match_count=3566, volume_count=1743)
# Record(ngram='wears', year=1861, match_count=2526, volume_count=1195)
# Record(ngram='wears', year=1862, match_count=2179, volume_count=1136)
# Record(ngram='wears', year=1863, match_count=2636, volume_count=1137)
# Record(ngram='wears', year=1864, match_count=3138, volume_count=1440)
# Record(ngram='wears', year=1865, match_count=2788, volume_count=1338)
# Record(ngram='wears', year=1866, match_count=3176, volume_count=1448)
# Record(ngram='wears', year=1867, match_count=3114, volume_count=1344)
# Record(ngram='wears', year=1868, match_count=3261, volume_count=1478)
# Record(ngram='wears', year=1869, match_count=3459, volume_count=1587)
# Record(ngram='wears', year=1870, match_count=3684, volume_count=1590)
# Record(ngram='wears', year=1871, match_count=3149, volume_count=1572)
# Record(ngram='wears', year=1872, match_count=4155, volume_count=1578)
# Record(ngram='wears', year=1873, match_count=3845, volume_count=1639)
# Record(ngram='wears', year=1874, match_count=3806, volume_count=1738)
# Record(ngram='wears', year=1875, match_count=3704, volume_count=1766)
# Record(ngram='wears', year=1876, match_count=4272, volume_count=1892)
# Record(ngram='wears', year=1877, match_count=3807, volume_count=1815)
# Record(ngram='wears', year=1878, match_count=4100, volume_count=1769)
# Record(ngram='wears', year=1879, match_count=4044, volume_count=1800)
# Record(ngram='wears', year=1880, match_count=4852, volume_count=2108)
# Record(ngram='wears', year=1881, match_count=4692, volume_count=2212)
# Record(ngram='wears', year=1882, match_count=5299, volume_count=2333)
# Record(ngram='wears', year=1883, match_count=6548, volume_count=2702)
# Record(ngram='wears', year=1884, match_count=5296, volume_count=2425)
# Record(ngram='wears', year=1885, match_count=5731, volume_count=2400)
# Record(ngram='wears', year=1886, match_count=4113, volume_count=1957)
# Record(ngram='wears', year=1887, match_count=5022, volume_count=2417)
# Record(ngram='wears', year=1888, match_count=4630, volume_count=2248)
# Record(ngram='wears', year=1889, match_count=4345, volume_count=2086)
# Record(ngram='wears', year=1890, match_count=4789, volume_count=2299)
# Record(ngram='wears', year=1891, match_count=5911, volume_count=2511)
# Record(ngram='wears', year=1892, match_count=6241, volume_count=2790)
# Record(ngram='wears', year=1893, match_count=5749, volume_count=2671)
# Record(ngram='wears', year=1894, match_count=5894, volume_count=2597)
# Record(ngram='wears', year=1895, match_count=6207, volume_count=2930)
# Record(ngram='wears', year=1896, match_count=7266, volume_count=3227)
# Record(ngram='wears', year=1897, match_count=7069, volume_count=3145)
# Record(ngram='wears', year=1898, match_count=6983, volume_count=3270)
# Record(ngram='wears', year=1899, match_count=8695, volume_count=3860)
# Record(ngram='wears', year=1900, match_count=9338, volume_count=4160)
# Record(ngram='wears', year=1901, match_count=8593, volume_count=3909)
# Record(ngram='wears', year=1902, match_count=8629, volume_count=4090)
# Record(ngram='wears', year=1903, match_count=8988, volume_count=3796)
# Record(ngram='wears', year=1904, match_count=10226, volume_count=4312)
# Record(ngram='wears', year=1905, match_count=8800, volume_count=3905)
# Record(ngram='wears', year=1906, match_count=9453, volume_count=4211)
# Record(ngram='wears', year=1907, match_count=13198, volume_count=4195)
# Record(ngram='wears', year=1908, match_count=8842, volume_count=4237)
# Record(ngram='wears', year=1909, match_count=8328, volume_count=3762)
# Record(ngram='wears', year=1910, match_count=9776, volume_count=4185)
# Record(ngram='wears', year=1911, match_count=8580, volume_count=3963)
# Record(ngram='wears', year=1912, match_count=9855, volume_count=4182)
# Record(ngram='wears', year=1913, match_count=8225, volume_count=3939)
# Record(ngram='wears', year=1914, match_count=12215, volume_count=3969)
# Record(ngram='wears', year=1915, match_count=7225, volume_count=3332)
# Record(ngram='wears', year=1916, match_count=7007, volume_count=3421)
# Record(ngram='wears', year=1917, match_count=7665, volume_count=3597)
# Record(ngram='wears', year=1918, match_count=6522, volume_count=3104)
# Record(ngram='wears', year=1919, match_count=6951, volume_count=3318)
# Record(ngram='wears', year=1920, match_count=7940, volume_count=3924)
# Record(ngram='wears', year=1921, match_count=7130, volume_count=3476)
# Record(ngram='wears', year=1922, match_count=8126, volume_count=3936)
# Record(ngram='wears', year=1923, match_count=8627, volume_count=3547)
# Record(ngram='wears', year=1924, match_count=7445, volume_count=3148)
# Record(ngram='wears', year=1925, match_count=7037, volume_count=3263)
# Record(ngram='wears', year=1926, match_count=6779, volume_count=3000)
# Record(ngram='wears', year=1927, match_count=7512, volume_count=3370)
# Record(ngram='wears', year=1928, match_count=7308, volume_count=3412)
# Record(ngram='wears', year=1929, match_count=7490, volume_count=3361)
# Record(ngram='wears', year=1930, match_count=7657, volume_count=3416)
# Record(ngram='wears', year=1931, match_count=7379, volume_count=3082)
# Record(ngram='wears', year=1932, match_count=5915, volume_count=2672)
# Record(ngram='wears', year=1933, match_count=4863, volume_count=2372)
# Record(ngram='wears', year=1934, match_count=5998, volume_count=2570)
# Record(ngram='wears', year=1935, match_count=6524, volume_count=2925)
# Record(ngram='wears', year=1936, match_count=6566, volume_count=3040)
# Record(ngram='wears', year=1937, match_count=6973, volume_count=3054)
# Record(ngram='wears', year=1938, match_count=7248, volume_count=3106)
# Record(ngram='wears', year=1939, match_count=6950, volume_count=2944)
# Record(ngram='wears', year=1940, match_count=6556, volume_count=2664)
# Record(ngram='wears', year=1941, match_count=5737, volume_count=2650)
# Record(ngram='wears', year=1942, match_count=6159, volume_count=2622)
# Record(ngram='wears', year=1943, match_count=5087, volume_count=2235)
# Record(ngram='wears', year=1944, match_count=4430, volume_count=2058)
# Record(ngram='wears', year=1945, match_count=4652, volume_count=2187)
# Record(ngram='wears', year=1946, match_count=6568, volume_count=2957)
# Record(ngram='wears', year=1947, match_count=7758, volume_count=3497)
# Record(ngram='wears', year=1948, match_count=8851, volume_count=3592)
# Record(ngram='wears', year=1949, match_count=8415, volume_count=3705)
# Record(ngram='wears', year=1950, match_count=8364, volume_count=3650)
# Record(ngram='wears', year=1951, match_count=7762, volume_count=3565)
# Record(ngram='wears', year=1952, match_count=7711, volume_count=3527)
# Record(ngram='wears', year=1953, match_count=8043, volume_count=3616)
# Record(ngram='wears', year=1954, match_count=8217, volume_count=3746)
# Record(ngram='wears', year=1955, match_count=8890, volume_count=3814)
# Record(ngram='wears', year=1956, match_count=9229, volume_count=4018)
# Record(ngram='wears', year=1957, match_count=9206, volume_count=4195)
# Record(ngram='wears', year=1958, match_count=8982, volume_count=4144)
# Record(ngram='wears', year=1959, match_count=9313, volume_count=4325)
# Record(ngram='wears', year=1960, match_count=10543, volume_count=4862)
# Record(ngram='wears', year=1961, match_count=11989, volume_count=5343)
# Record(ngram='wears', year=1962, match_count=12802, volume_count=5782)
# Record(ngram='wears', year=1963, match_count=13305, volume_count=5947)
# Record(ngram='wears', year=1964, match_count=13868, volume_count=6023)
# Record(ngram='wears', year=1965, match_count=14783, volume_count=6537)
# Record(ngram='wears', year=1966, match_count=15107, volume_count=6901)
# Record(ngram='wears', year=1967, match_count=18311, volume_count=7521)
# Record(ngram='wears', year=1968, match_count=19867, volume_count=8353)
# Record(ngram='wears', year=1969, match_count=18889, volume_count=8287)
# Record(ngram='wears', year=1970, match_count=20932, volume_count=8897)
# Record(ngram='wears', year=1971, match_count=18676, volume_count=8490)
# Record(ngram='wears', year=1972, match_count=18893, volume_count=8743)
# Record(ngram='wears', year=1973, match_count=18691, volume_count=8397)
# Record(ngram='wears', year=1974, match_count=18061, volume_count=8156)
# Record(ngram='wears', year=1975, match_count=20172, volume_count=8113)
# Record(ngram='wears', year=1976, match_count=18343, volume_count=8540)
# Record(ngram='wears', year=1977, match_count=20643, volume_count=8908)
# Record(ngram='wears', year=1978, match_count=20502, volume_count=8648)
# Record(ngram='wears', year=1979, match_count=19967, volume_count=8804)
# Record(ngram='wears', year=1980, match_count=21598, volume_count=8953)
# Record(ngram='wears', year=1981, match_count=20233, volume_count=8731)
# Record(ngram='wears', year=1982, match_count=21824, volume_count=9428)
# Record(ngram='wears', year=1983, match_count=22098, volume_count=9387)
# Record(ngram='wears', year=1984, match_count=24581, volume_count=10103)
# Record(ngram='wears', year=1985, match_count=25338, volume_count=10347)
# Record(ngram='wears', year=1986, match_count=25658, volume_count=10980)
# Record(ngram='wears', year=1987, match_count=26772, volume_count=11532)
# Record(ngram='wears', year=1988, match_count=27498, volume_count=12052)
# Record(ngram='wears', year=1989, match_count=30340, volume_count=12787)
# Record(ngram='wears', year=1990, match_count=31317, volume_count=13890)
# Record(ngram='wears', year=1991, match_count=30422, volume_count=13758)
# Record(ngram='wears', year=1992, match_count=34433, volume_count=14966)
# Record(ngram='wears', year=1993, match_count=36724, volume_count=14990)
# Record(ngram='wears', year=1994, match_count=36562, volume_count=16065)
# Record(ngram='wears', year=1995, match_count=39907, volume_count=16886)
# Record(ngram='wears', year=1996, match_count=40836, volume_count=17798)
# Record(ngram='wears', year=1997, match_count=41502, volume_count=18331)
# Record(ngram='wears', year=1998, match_count=44330, volume_count=19423)
# Record(ngram='wears', year=1999, match_count=46747, volume_count=20509)
# Record(ngram='wears', year=2000, match_count=53026, volume_count=23524)
# Record(ngram='wears', year=2001, match_count=55668, volume_count=23947)
# Record(ngram='wears', year=2002, match_count=59766, volume_count=26158)
# Record(ngram='wears', year=2003, match_count=66725, volume_count=29169)
# ...
# Record(ngram='spectacles', year=1797, match_count=193, volume_count=106)
# Record(ngram='spectacles', year=1798, match_count=178, volume_count=107)
# Record(ngram='spectacles', year=1799, match_count=204, volume_count=94)
# Record(ngram='spectacles', year=1800, match_count=332, volume_count=152)
# Record(ngram='spectacles', year=1801, match_count=460, volume_count=227)
# Record(ngram='spectacles', year=1802, match_count=302, volume_count=187)
# Record(ngram='spectacles', year=1803, match_count=594, volume_count=258)
# Record(ngram='spectacles', year=1804, match_count=530, volume_count=243)
# Record(ngram='spectacles', year=1805, match_count=302, volume_count=168)
# Record(ngram='spectacles', year=1806, match_count=500, volume_count=288)
# Record(ngram='spectacles', year=1807, match_count=502, volume_count=313)
# Record(ngram='spectacles', year=1808, match_count=549, volume_count=284)
# Record(ngram='spectacles', year=1809, match_count=610, volume_count=309)
# Record(ngram='spectacles', year=1810, match_count=495, volume_count=300)
# Record(ngram='spectacles', year=1811, match_count=788, volume_count=338)
# Record(ngram='spectacles', year=1812, match_count=515, volume_count=280)
# Record(ngram='spectacles', year=1813, match_count=573, volume_count=270)
# Record(ngram='spectacles', year=1814, match_count=645, volume_count=331)
# Record(ngram='spectacles', year=1815, match_count=712, volume_count=337)
# Record(ngram='spectacles', year=1816, match_count=634, volume_count=334)
# Record(ngram='spectacles', year=1817, match_count=777, volume_count=396)
# Record(ngram='spectacles', year=1818, match_count=844, volume_count=430)
# Record(ngram='spectacles', year=1819, match_count=735, volume_count=422)
# Record(ngram='spectacles', year=1820, match_count=961, volume_count=552)
# Record(ngram='spectacles', year=1821, match_count=851, volume_count=427)
# Record(ngram='spectacles', year=1822, match_count=1002, volume_count=567)
# Record(ngram='spectacles', year=1823, match_count=1255, volume_count=660)
# Record(ngram='spectacles', year=1824, match_count=1520, volume_count=720)
# Record(ngram='spectacles', year=1825, match_count=1692, volume_count=827)
# Record(ngram='spectacles', year=1826, match_count=1037, volume_count=545)
# Record(ngram='spectacles', year=1827, match_count=1176, volume_count=568)
# Record(ngram='spectacles', year=1828, match_count=1098, volume_count=608)
# Record(ngram='spectacles', year=1829, match_count=945, volume_count=529)
# Record(ngram='spectacles', year=1830, match_count=1314, volume_count=687)
# Record(ngram='spectacles', year=1831, match_count=1406, volume_count=696)
# Record(ngram='spectacles', year=1832, match_count=1301, volume_count=626)
# Record(ngram='spectacles', year=1833, match_count=1564, volume_count=692)
# Record(ngram='spectacles', year=1834, match_count=1476, volume_count=723)
# Record(ngram='spectacles', year=1835, match_count=1535, volume_count=809)
# Record(ngram='spectacles', year=1836, match_count=1700, volume_count=846)
# Record(ngram='spectacles', year=1837, match_count=1602, volume_count=734)
# Record(ngram='spectacles', year=1838, match_count=1730, volume_count=791)
# Record(ngram='spectacles', year=1839, match_count=1695, volume_count=823)
# Record(ngram='spectacles', year=1840, match_count=1915, volume_count=812)
# Record(ngram='spectacles', year=1841, match_count=1732, volume_count=776)
# Record(ngram='spectacles', year=1842, match_count=1498, volume_count=684)
# Record(ngram='spectacles', year=1843, match_count=1504, volume_count=741)
# Record(ngram='spectacles', year=1844, match_count=1725, volume_count=862)
# Record(ngram='spectacles', year=1845, match_count=2045, volume_count=955)
# Record(ngram='spectacles', year=1846, match_count=2115, volume_count=940)
# Record(ngram='spectacles', year=1847, match_count=1707, volume_count=866)
# Record(ngram='spectacles', year=1848, match_count=1989, volume_count=933)
# Record(ngram='spectacles', year=1849, match_count=1984, volume_count=950)
# Record(ngram='spectacles', year=1850, match_count=2778, volume_count=1072)
# Record(ngram='spectacles', year=1851, match_count=2232, volume_count=1021)
# Record(ngram='spectacles', year=1852, match_count=2673, volume_count=1165)
# Record(ngram='spectacles', year=1853, match_count=3070, volume_count=1373)
# Record(ngram='spectacles', year=1854, match_count=3266, volume_count=1471)
# Record(ngram='spectacles', year=1855, match_count=2946, volume_count=1355)
# Record(ngram='spectacles', year=1856, match_count=3638, volume_count=1467)
# Record(ngram='spectacles', year=1857, match_count=2780, volume_count=1282)
# Record(ngram='spectacles', year=1858, match_count=2351, volume_count=1069)
# Record(ngram='spectacles', year=1859, match_count=2823, volume_count=1284)
# Record(ngram='spectacles', year=1860, match_count=3028, volume_count=1421)
# Record(ngram='spectacles', year=1861, match_count=2194, volume_count=1039)
# Record(ngram='spectacles', year=1862, match_count=1973, volume_count=885)
# Record(ngram='spectacles', year=1863, match_count=1991, volume_count=914)
# Record(ngram='spectacles', year=1864, match_count=3440, volume_count=1112)
# Record(ngram='spectacles', year=1865, match_count=2456, volume_count=1081)
# Record(ngram='spectacles', year=1866, match_count=2680, volume_count=1185)
# Record(ngram='spectacles', year=1867, match_count=2469, volume_count=1078)
# Record(ngram='spectacles', year=1868, match_count=3202, volume_count=1170)
# Record(ngram='spectacles', year=1869, match_count=3642, volume_count=1251)
# Record(ngram='spectacles', year=1870, match_count=2858, volume_count=1123)
# Record(ngram='spectacles', year=1871, match_count=3119, volume_count=1267)
# Record(ngram='spectacles', year=1872, match_count=2759, volume_count=1204)
# Record(ngram='spectacles', year=1873, match_count=3187, volume_count=1270)
# Record(ngram='spectacles', year=1874, match_count=3090, volume_count=1345)
# Record(ngram='spectacles', year=1875, match_count=3574, volume_count=1378)
# Record(ngram='spectacles', year=1876, match_count=3521, volume_count=1390)
# Record(ngram='spectacles', year=1877, match_count=3107, volume_count=1397)
# Record(ngram='spectacles', year=1878, match_count=3276, volume_count=1368)
# Record(ngram='spectacles', year=1879, match_count=3100, volume_count=1360)
# Record(ngram='spectacles', year=1880, match_count=4370, volume_count=1665)
# Record(ngram='spectacles', year=1881, match_count=3586, volume_count=1624)
# Record(ngram='spectacles', year=1882, match_count=4374, volume_count=1812)
# Record(ngram='spectacles', year=1883, match_count=5106, volume_count=2083)
# Record(ngram='spectacles', year=1884, match_count=4077, volume_count=1798)
# Record(ngram='spectacles', year=1885, match_count=4151, volume_count=1797)
# Record(ngram='spectacles', year=1886, match_count=3313, volume_count=1410)
# Record(ngram='spectacles', year=1887, match_count=4169, volume_count=1834)
# Record(ngram='spectacles', year=1888, match_count=3751, volume_count=1674)
# Record(ngram='spectacles', year=1889, match_count=3557, volume_count=1442)
# Record(ngram='spectacles', year=1890, match_count=3445, volume_count=1638)
# Record(ngram='spectacles', year=1891, match_count=4451, volume_count=1855)
# Record(ngram='spectacles', year=1892, match_count=4815, volume_count=2094)
# Record(ngram='spectacles', year=1893, match_count=4674, volume_count=1948)
# Record(ngram='spectacles', year=1894, match_count=4451, volume_count=1978)
# Record(ngram='spectacles', year=1895, match_count=4729, volume_count=2139)
# Record(ngram='spectacles', year=1896, match_count=4964, volume_count=2296)
# Record(ngram='spectacles', year=1897, match_count=5028, volume_count=2230)
# Record(ngram='spectacles', year=1898, match_count=5656, volume_count=2430)
# Record(ngram='spectacles', year=1899, match_count=7477, volume_count=3086)
# Record(ngram='spectacles', year=1900, match_count=8551, volume_count=3438)
# Record(ngram='spectacles', year=1901, match_count=6811, volume_count=2926)
# Record(ngram='spectacles', year=1902, match_count=6020, volume_count=2784)
# Record(ngram='spectacles', year=1903, match_count=5679, volume_count=2597)
# Record(ngram='spectacles', year=1904, match_count=7210, volume_count=3244)
# Record(ngram='spectacles', year=1905, match_count=5936, volume_count=2800)
# Record(ngram='spectacles', year=1906, match_count=6183, volume_count=2885)
# Record(ngram='spectacles', year=1907, match_count=6343, volume_count=2826)
# Record(ngram='spectacles', year=1908, match_count=6528, volume_count=2874)
# Record(ngram='spectacles', year=1909, match_count=5433, volume_count=2465)
# Record(ngram='spectacles', year=1910, match_count=5707, volume_count=2689)
# Record(ngram='spectacles', year=1911, match_count=5922, volume_count=2585)
# Record(ngram='spectacles', year=1912, match_count=5746, volume_count=2795)
# Record(ngram='spectacles', year=1913, match_count=5732, volume_count=2645)
# Record(ngram='spectacles', year=1914, match_count=5176, volume_count=2453)
# Record(ngram='spectacles', year=1915, match_count=4098, volume_count=2058)
# Record(ngram='spectacles', year=1916, match_count=4678, volume_count=2225)
# Record(ngram='spectacles', year=1917, match_count=4817, volume_count=2313)
# Record(ngram='spectacles', year=1918, match_count=3942, volume_count=1866)
# Record(ngram='spectacles', year=1919, match_count=4504, volume_count=2033)
# Record(ngram='spectacles', year=1920, match_count=5713, volume_count=2522)
# Record(ngram='spectacles', year=1921, match_count=5098, volume_count=2275)
# Record(ngram='spectacles', year=1922, match_count=5630, volume_count=2589)
# Record(ngram='spectacles', year=1923, match_count=5267, volume_count=2376)
# Record(ngram='spectacles', year=1924, match_count=4997, volume_count=2264)
# Record(ngram='spectacles', year=1925, match_count=5272, volume_count=2331)
# Record(ngram='spectacles', year=1926, match_count=4598, volume_count=2069)
# Record(ngram='spectacles', year=1927, match_count=5190, volume_count=2398)
# Record(ngram='spectacles', year=1928, match_count=5470, volume_count=2360)
# Record(ngram='spectacles', year=1929, match_count=5366, volume_count=2312)
# Record(ngram='spectacles', year=1930, match_count=5806, volume_count=2493)
# Record(ngram='spectacles', year=1931, match_count=5368, volume_count=2323)
# Record(ngram='spectacles', year=1932, match_count=5173, volume_count=2045)
# Record(ngram='spectacles', year=1933, match_count=4355, volume_count=1798)
# Record(ngram='spectacles', year=1934, match_count=4947, volume_count=1975)
# Record(ngram='spectacles', year=1935, match_count=5103, volume_count=2137)
# Record(ngram='spectacles', year=1936, match_count=5347, volume_count=2244)
# Record(ngram='spectacles', year=1937, match_count=5432, volume_count=2277)
# Record(ngram='spectacles', year=1938, match_count=5279, volume_count=2246)
# Record(ngram='spectacles', year=1939, match_count=5014, volume_count=2067)
# Record(ngram='spectacles', year=1940, match_count=4297, volume_count=1917)
# Record(ngram='spectacles', year=1941, match_count=3926, volume_count=1757)
# Record(ngram='spectacles', year=1942, match_count=4062, volume_count=1661)
# Record(ngram='spectacles', year=1943, match_count=3195, volume_count=1487)
# Record(ngram='spectacles', year=1944, match_count=3108, volume_count=1393)
# Record(ngram='spectacles', year=1945, match_count=3596, volume_count=1527)
# Record(ngram='spectacles', year=1946, match_count=5169, volume_count=2257)
# Record(ngram='spectacles', year=1947, match_count=5649, volume_count=2356)
# Record(ngram='spectacles', year=1948, match_count=5165, volume_count=2362)
# Record(ngram='spectacles', year=1949, match_count=6777, volume_count=2581)
# Record(ngram='spectacles', year=1950, match_count=6078, volume_count=2616)
# Record(ngram='spectacles', year=1951, match_count=5615, volume_count=2411)
# Record(ngram='spectacles', year=1952, match_count=5958, volume_count=2505)
# Record(ngram='spectacles', year=1953, match_count=5447, volume_count=2415)
# Record(ngram='spectacles', year=1954, match_count=5984, volume_count=2460)
# Record(ngram='spectacles', year=1955, match_count=6005, volume_count=2626)
# Record(ngram='spectacles', year=1956, match_count=5989, volume_count=2781)
# Record(ngram='spectacles', year=1957, match_count=6799, volume_count=3008)
# Record(ngram='spectacles', year=1958, match_count=6223, volume_count=2802)
# Record(ngram='spectacles', year=1959, match_count=6994, volume_count=2964)
# Record(ngram='spectacles', year=1960, match_count=7797, volume_count=3460)
# Record(ngram='spectacles', year=1961, match_count=8491, volume_count=3541)
# Record(ngram='spectacles', year=1962, match_count=9123, volume_count=3863)
# Record(ngram='spectacles', year=1963, match_count=9527, volume_count=4170)
# Record(ngram='spectacles', year=1964, match_count=8256, volume_count=3785)
# Record(ngram='spectacles', year=1965, match_count=9550, volume_count=4355)
# Record(ngram='spectacles', year=1966, match_count=10346, volume_count=4609)
# Record(ngram='spectacles', year=1967, match_count=10774, volume_count=4830)
# Record(ngram='spectacles', year=1968, match_count=13120, volume_count=5670)
# Record(ngram='spectacles', year=1969, match_count=10998, volume_count=5200)
# Record(ngram='spectacles', year=1970, match_count=13144, volume_count=5562)
# Record(ngram='spectacles', year=1971, match_count=10697, volume_count=5050)
# Record(ngram='spectacles', year=1972, match_count=10505, volume_count=5195)
# Record(ngram='spectacles', year=1973, match_count=9864, volume_count=4697)
# Record(ngram='spectacles', year=1974, match_count=9891, volume_count=4634)
# Record(ngram='spectacles', year=1975, match_count=9560, volume_count=4584)
# Record(ngram='spectacles', year=1976, match_count=9910, volume_count=4755)
# Record(ngram='spectacles', year=1977, match_count=10456, volume_count=4790)
# Record(ngram='spectacles', year=1978, match_count=10547, volume_count=4667)
# Record(ngram='spectacles', year=1979, match_count=10165, volume_count=4782)
# Record(ngram='spectacles', year=1980, match_count=11139, volume_count=4924)
# Record(ngram='spectacles', year=1981, match_count=10608, volume_count=4772)
# Record(ngram='spectacles', year=1982, match_count=11133, volume_count=4878)
# Record(ngram='spectacles', year=1983, match_count=10792, volume_count=5030)
# Record(ngram='spectacles', year=1984, match_count=12642, volume_count=5374)
# Record(ngram='spectacles', year=1985, match_count=13120, volume_count=5445)
# Record(ngram='spectacles', year=1986, match_count=14004, volume_count=5904)
# Record(ngram='spectacles', year=1987, match_count=13563, volume_count=5938)
# Record(ngram='spectacles', year=1988, match_count=14071, volume_count=6130)
# Record(ngram='spectacles', year=1989, match_count=14404, volume_count=6742)
# Record(ngram='spectacles', year=1990, match_count=16171, volume_count=7224)
# Record(ngram='spectacles', year=1991, match_count=16290, volume_count=6971)
# Record(ngram='spectacles', year=1992, match_count=17866, volume_count=7613)
# Record(ngram='spectacles', year=1993, match_count=17780, volume_count=7388)
# Record(ngram='spectacles', year=1994, match_count=18974, volume_count=7970)
# Record(ngram='spectacles', year=1995, match_count=18719, volume_count=8034)
# Record(ngram='spectacles', year=1996, match_count=20996, volume_count=8885)
# Record(ngram='spectacles', year=1997, match_count=19806, volume_count=8593)
# Record(ngram='spectacles', year=1998, match_count=22646, volume_count=9315)
# Record(ngram='spectacles', year=1999, match_count=23662, volume_count=10121)
# Record(ngram='spectacles', year=2000, match_count=28050, volume_count=11782)
# Record(ngram='spectacles', year=2001, match_count=26679, volume_count=11586)
# Record(ngram='spectacles', year=2002, match_count=28246, volume_count=12177)
# Record(ngram='spectacles', year=2003, match_count=31730, volume_count=13497)
# Record(ngram='spectacles', year=2004, match_count=40035, volume_count=16908)
# Record(ngram='spectacles', year=2005, match_count=36352, volume_count=15618)
# Record(ngram='spectacles', year=2006, match_count=39914, volume_count=17290)
# Record(ngram='spectacles', year=2007, match_count=52647, volume_count=20589)
# Record(ngram='spectacles', year=2008, match_count=79309, volume_count=33715)
# Total seconds: 305
# [('wears', 1, 0.53101), ('wears', 1, 0.53101), ('spectacles', 1, 0.51295)]

# %%
# WARNING: THIS CODE TAKES FOREVER TO RUN
# import string

# a_through_z = string.ascii_lowercase
# unigram_total_match_count = 0
# fname, url, records = next(readline_google_store(ngram_len=1, indices=a_through_z))

# i = 0
# try:
#     while True:
#         record = next(records)
#         count += record.match_count
#         if i%10000000 == 0:
#             print(record)
#             print('Currently at: ' + str(count))
#         i += 1
# except StopIteration:
#     pass

# print('Count is ' + str(count))
